# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import datetime
import jpholiday
import statsmodels.api as sm
from statsmodels.graphics import tsaplots
# from optuna.integration import lightgbm as lgb
import lightgbm as lgb
from sklearn.metrics import  log_loss
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from datetime import date, timedelta
import sklearn.metrics
import optuna 
from dateutil.relativedelta import relativedelta
import pandas_profiling as pdp


# %matplotlib inline

# %% [markdown]
# # 基準モデルの作成

# %%
FILE_PATH = '/Users/atsushisato/git_clone/ai_quest_season2/data/'

train_data = pd.read_csv(FILE_PATH + 'external/train.csv').rename(columns={'顧客ID':'uuid', 'クーポンID':'coupon_id', 'クーポン利用':'coupon_use_result'})
test_data = pd.read_csv(FILE_PATH + 'external/test.csv').rename(columns={'顧客ID':'uuid', 'クーポンID':'coupon_id'})
customer_df = pd.read_csv(FILE_PATH + 'interim/customer_df.csv')

# %% [markdown]
# # 特徴量作成

# %%
#特徴量作成関数（trainとtestで異なる処理が可能）
def create_feature_separate(dataframe):
    # issue 9/10 カテゴリ変数の数値変換 
    dataframe = category_to_int_conversion(dataframe)
    
    # issue 11 カテゴリ別商品単価
    dataframe['unit_price_category'] = dataframe.apply(lambda x: 
                                unit_price_category(x['purchase_product_num'], x['coupon_use'], x['purchase_price']),axis=1)
    # issue 16 総購入商品の平均
    dataframe['purchase_price_average'] = dataframe.apply(lambda x: 
                                purchase_price_average(x['all_purchase_price'], x['visits_frequency']),axis=1)   
    # issue 20 平均来店周期
    dataframe['visit_cycle'] = dataframe.apply(lambda x:
                                visit_cycle(x['visits_frequency'], x['pass_days']),axis=1)
    # issue 21 経過日数と来店頻度の比較
    dataframe['visit_cycle_flg'] = dataframe.apply(lambda x: 
                                visit_cycle_flg(x['visit_cycle'], x['pass_days']),axis=1) 
    # issue 22 総購入金額に占めるカテゴリ別の購入金額比率
    dataframe['ratio_category'] = dataframe.apply(lambda x:
                                ratio_category(x['all_purchase_price'], x['purchase_price']),axis=1)
    # issue 23 大人の数
    dataframe['adult_num'] = dataframe['fammily_num'] - dataframe['child_num']
    
    # issue 24 カテゴリ別平均購入金額
    dataframe['purchase_price_category_average'] = dataframe.apply(lambda x:
                                purchase_price_category_average(x['purchase_price'], x['purchase_product_num'],x['coupon_use']),axis=1)
    # issue 28 家族1人あたりの総購入金額
    dataframe['purchase_price_1person'] = dataframe.apply(lambda x:
                                purchase_price_1person(x['all_purchase_price'], x['fammily_num']),axis=1)
    # issue 29 1日あたりの購入金額
    dataframe['purchase_price_1day'] = dataframe.apply(lambda x :
                                purchase_price_1day(x['all_purchase_price'], x['pass_days']),axis=1)
    
    
    dataframe = dataframe.drop(['category_id', 'house_flg', 'marry_flg', 'age', 'visit_cycle_flg', 'category_id'],axis=1)
    return dataframe

# %%
#===================================================================================
#特徴量作成関数
# issue 9/10 カテゴリ変数の数値変換    
def category_to_int_conversion(dataframe):
    marry_dict = {'無回答':None, '独身':0, '既婚':1}
    dataframe['marry_flg'] = dataframe['marry'].apply(lambda x: marry_dict.get(x))
    
    dataframe['age'] = dataframe['age_range'].apply(lambda x: int(x[:2]))
    dataframe['category_id'] = dataframe['category_id'].apply(lambda x: int(x[1:]))
    
    dataframe = dataframe.drop(['age_range','marry','category'],axis=1)
    return dataframe

# issue 11 カテゴリ別商品単価
def unit_price_category(product_num, coupon_use, price):
    if coupon_use != 0:
        price = price + abs(coupon_use)
    
    if price != 0:
        return int(price / product_num)
    else:
        return 0
    
# issue 16 総購入商品の平均
def purchase_price_average(all_purchase_price, visits_frequency):
    if (all_purchase_price != 0) & (visits_frequency != 0):
        one_purchase_price =  int(all_purchase_price / visits_frequency)            
    else:
        one_purchase_price =  0
    return one_purchase_price

# issue 20 平均来店周期
def visit_cycle(visits_frequency, pass_days):
    all_days = 60
    if visits_frequency != 0:
        cycle = int((all_days - pass_days) / visits_frequency)
    else:
        cycle = 0
    return cycle

# issue 21 経過日数と来店頻度の比較
def visit_cycle_flg(visit_cycle, pass_days):
    if visit_cycle <= pass_days:
        return 1
    else:
        return 0
    
# issue 22 総購入金額に占めるカテゴリ別の購入金額比率
def ratio_category(all_purchase_price, purchase_price):
    if purchase_price != 0:
        ratio = purchase_price / all_purchase_price
    else:
        ratio = 0
    return ratio

# issue 24 カテゴリ別平均購入金額
def purchase_price_category_average(purchase_price, purchase_product_num, coupon_use):
    if purchase_product_num != 0:
        purchase_price = purchase_price + abs(coupon_use)
        average_purchase = int(purchase_price / purchase_product_num)
    else:
        average_purchase = 0
    return average_purchase
    
# issue 28 家族1人あたりの総購入金額
def purchase_price_1person(all_purchase_price, fammily_num):
    if all_purchase_price != 0:
        return int(all_purchase_price / fammily_num)
    else:
        return 0

# issue 29 1日あたりの購入金額
def purchase_price_1day(all_purchase_price, pass_days):
    if all_purchase_price != 0:
        all_days = 60
        use_days = all_days - pass_days + 1
        return int(all_purchase_price / use_days)
    else:
        return 0
    
# issue 19 欠損値削除（購入履歴はあるが来店履歴がないuuid）
def drop_missing_value(dataframe):
    drop_uuid = dataframe.query("(visits_frequency ==0 )& (all_purchase_price != 0)")['uuid'].unique()
    dataframe = dataframe.query("uuid not in @drop_uuid") 
    return dataframe

# %%
#train_dataとtest_dataの特徴量作成
train_data = pd.merge(train_data, customer_df, on=['uuid', 'coupon_id'],how='inner')
test_data = pd.merge(test_data, customer_df, on=['uuid', 'coupon_id'],how='inner')

#特徴量作成（train_dataとtest_dataで異なる処理が可能）
train_data = create_feature_separate(train_data)
test_data = create_feature_separate(test_data)
train_data = drop_missing_value(train_data)

# %%
# pdp.ProfileReport(train_data.query("coupon_use_result == 1"))

# %%
sorted(train_data.columns)
# Out:
# ['adult_num',
#  'all_purchase_price',
#  'child_num',
#  'coupon_id',
#  'coupon_use',
#  'coupon_use_result',
#  'fammily_num',
#  'income',
#  'pass_days',
#  'purchase_num',
#  'purchase_price',
#  'purchase_price_1day',
#  'purchase_price_1person',
#  'purchase_price_average',
#  'purchase_price_category_average',
#  'purchase_product_num',
#  'ratio_category',
#  'unit_price_category',
#  'uuid',
#  'visit_cycle',
#  'visits_frequency']

# %%
train_data.head(11)
# Out:
#     uuid  coupon_id  coupon_use_result  fammily_num  child_num  income  \
# 0      1          1                  0            1          0       5
# 1      1          2                  0            1          0       5
# 2      1          3                  0            1          0       5
# 3      1          4                  0            1          0       5
# 4      1          5                  0            1          0       5
# 5      1          6                  0            1          0       5
# 6      1          7                  0            1          0       5
# 7      1          8                  0            1          0       5
# 8      1          9                  0            1          0       5
# 9      1         10                  0            1          0       5
# 10     1         11                  0            1          0       5
#
#     visits_frequency  pass_days  all_purchase_price  purchase_num  ...  \
# 0                  9         19               56562             1  ...
# 1                  9         19               56562             1  ...
# 2                  9         19               56562             0  ...
# 3                  9         19               56562             1  ...
# 4                  9         19               56562             9  ...
# 5                  9         19               56562             0  ...
# 6                  9         19               56562             0  ...
# 7                  9         19               56562             9  ...
# 8                  9         19               56562             9  ...
# 9                  9         19               56562             0  ...
# 10                 9         19               56562             0  ...
#
#     coupon_use  purchase_price  unit_price_category  purchase_price_average  \
# 0            0             534                  267                    6284
# 1            0            2803                 1401                    6284
# 2            0               0                    0                    6284
# 3            0             764                  764                    6284
# 4            0            4981                  293                    6284
# 5            0               0                    0                    6284
# 6            0               0                    0                    6284
# 7            0           22620                  293                    6284
# 8            0           24860                 2486                    6284
# 9            0               0                    0                    6284
# 10           0               0                    0                    6284
#
#     visit_cycle  ratio_category  adult_num  purchase_price_category_average  \
# 0             4        0.009441          1                              267
# 1             4        0.049556          1                             1401
# 2             4        0.000000          1                                0
# 3             4        0.013507          1                              764
# 4             4        0.088063          1                              293
# 5             4        0.000000          1                                0
# 6             4        0.000000          1                                0
# 7             4        0.399915          1                              293
# 8             4        0.439518          1                             2486
# 9             4        0.000000          1                                0
# 10            4        0.000000          1                                0
#
#     purchase_price_1person  purchase_price_1day
# 0                    56562                 1346
# 1                    56562                 1346
# 2                    56562                 1346
# 3                    56562                 1346
# 4                    56562                 1346
# 5                    56562                 1346
# 6                    56562                 1346
# 7                    56562                 1346
# 8                    56562                 1346
# 9                    56562                 1346
# 10                   56562                 1346
#
# [11 rows x 21 columns]

# %%
#LightGBMによるモデル作成
train_x = train_data.drop(['coupon_use_result','uuid'], axis=1)
train_y = train_data[['coupon_use_result']]
val_size = 4
uuid_num = train_data['uuid'].nunique()
train_uuid = int((uuid_num/val_size)*(val_size-1))
filter_idx = (train_uuid*11)-1
tr_x, va_x = train_x.iloc[:filter_idx], train_x.iloc[filter_idx:]
tr_y, va_y = train_y.iloc[:filter_idx], train_y.iloc[filter_idx:]

score_dict = {}
# params = {
# 'objective': 'binary',
#  'metric': 'binary_logloss',
#  'seed': 118,
#  'lambda_l1': 0.00004456120176148555,
#  'lambda_l2': 0.0000004244567009620525,
#  'num_leaves': 371,
#  'feature_fraction': 0.6045840940131413,
#  'bagging_fraction': 0.7154034241314151,
#  'bagging_freq': 6,
#  'min_child_samples': 58
#         }

num_round =1000
# categorical_feature = ['marry_flg','age']
scores = []
lgb_train = lgb.Dataset(tr_x, tr_y)
lgb_eval = lgb.Dataset(va_x, va_y)

best_params, tuning_history = dict(), list()
# for i in range(100):
params = {
'objective': 'binary',
 'metric': 'binary_logloss',
 'seed':70,
'lambda_l1': 0.003158141941182639,
 'lambda_l2': 0.0008853206993091085,
 'num_leaves': 380,
 'feature_fraction': 0.5686541926682908,
 'bagging_fraction': 0.6569913398412971,
 'bagging_freq': 0,
 'min_child_samples': 5
 }
model = lgb.train(params, 
                  lgb_train, 
                  verbose_eval=50,  # 50イテレーション毎に学習結果出力
#                   categorical_feature = categorical_feature,
                  num_boost_round=num_round, 
                  early_stopping_rounds=100,
                  valid_names=['train', 'valid'], 
                  valid_sets=[lgb_train, lgb_eval]
                 )

va_pred = model.predict(va_x)
score = log_loss(va_y, va_pred)
scores.append(score)
#     score_dict[i] = score
#     print("="*80)

print("平均logloss：",np.mean(scores))
# Out:
# Training until validation scores don't improve for 100 rounds
# [50]	train's binary_logloss: 0.000522087	valid's binary_logloss: 0.0763184
# [100]	train's binary_logloss: 6.71439e-05	valid's binary_logloss: 0.0984091
# Early stopping, best iteration is:
# [10]	train's binary_logloss: 0.0142828	valid's binary_logloss: 0.0497867
# 平均logloss： 0.04978668763053791

# %%
score_dict
# Out:
# {}

# %%
scores
# Out:
# [0.04978668763053791]

# %%
#テストデータの予測
pred = model.predict(test_data.drop('uuid',axis=1))
pred = pd.Series(pred, name='pred')

# %%
# 特徴量重要度の算出 (データフレームで取得)
cols = list(train_x.columns)         # 特徴量名のリスト
f_importance = np.array(model.feature_importance()) # 特徴量重要度の算出
f_importance = f_importance / np.sum(f_importance)  # 正規化(必要ない場合はコメントアウト)
df_importance = pd.DataFrame({'feature':cols, 'importance':f_importance})
df_importance = df_importance.sort_values('importance', ascending=False) # 降順ソート
display(df_importance)
# Out:
#                             feature  importance
# 11              unit_price_category    0.107547
# 10                   purchase_price    0.092453
# 18              purchase_price_1day    0.081132
# 4                  visits_frequency    0.079245
# 0                         coupon_id    0.075472
# 14                   ratio_category    0.069811
# 6                all_purchase_price    0.067925
# 12           purchase_price_average    0.066038
# 8              purchase_product_num    0.060377
# 3                            income    0.060377
# 17           purchase_price_1person    0.054717
# 7                      purchase_num    0.037736
# 9                        coupon_use    0.037736
# 1                       fammily_num    0.032075
# 5                         pass_days    0.028302
# 16  purchase_price_category_average    0.026415
# 13                      visit_cycle    0.015094
# 15                        adult_num    0.005660
# 2                         child_num    0.001887

# %%
pred
# Out:
# 0       0.004930
# 1       0.004930
# 2       0.004930
# 3       0.004930
# 4       0.006408
#           ...
# 3911    0.004934
# 3912    0.012246
# 3913    0.004934
# 3914    0.004936
# 3915    0.013915
# Name: pred, Length: 3916, dtype: float64

# %%
def round_score(pred):
    if pred <= 0.0056:
        pred = 0
    elif pred >= 0.9944:
        pred = 1
    return pred

# %%
pred = pred.apply(lambda x: round_score(x))
result = test_data.join(pred)[['uuid', 'coupon_id', 'pred']]
result = result.pivot(index='uuid', columns='coupon_id', values='pred')

# %%
pred.min()
# Out:
# 0.0

# %%
pred.max()
# Out:
# 0.8808158900658125

# %%
result
# Out:
# coupon_id        1         2         3         4         5         6   \
# uuid
# 357        0.000000  0.000000  0.000000  0.000000  0.006408  0.000000
# 358        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 359        0.000000  0.000000  0.021344  0.021220  0.006498  0.021299
# 360        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 361        0.000000  0.072179  0.028101  0.000000  0.028659  0.000000
# ...             ...       ...       ...       ...       ...       ...
# 708        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 709        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 710        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 711        0.018502  0.000000  0.006397  0.006761  0.010398  0.000000
# 712        0.008465  0.008465  0.000000  0.000000  0.000000  0.000000
#
# coupon_id        7         8         9         10        11
# uuid
# 357        0.000000  0.131686  0.006337  0.000000  0.000000
# 358        0.000000  0.055225  0.006616  0.000000  0.000000
# 359        0.021299  0.638803  0.480607  0.006289  0.006574
# 360        0.000000  0.000000  0.000000  0.000000  0.000000
# 361        0.000000  0.007444  0.006187  0.007633  0.008241
# ...             ...       ...       ...       ...       ...
# 708        0.000000  0.006525  0.000000  0.000000  0.000000
# 709        0.011134  0.005928  0.000000  0.000000  0.000000
# 710        0.000000  0.000000  0.000000  0.000000  0.000000
# 711        0.005993  0.413493  0.020336  0.000000  0.006269
# 712        0.000000  0.012246  0.000000  0.000000  0.013915
#
# [356 rows x 11 columns]

# %%
result.to_csv('/Users/atsushisato/git_clone/ai_quest_season2/models/model.csv',header=False)

# %%
pred.nunique()
# Out:
# 857

# %% [markdown]
# # optunaによるパラメータ調整

# %%
model.params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-af908345f5b5> in <module>
# ----> 1 model.params
#
# NameError: name 'model' is not defined

# %%
# パラメータ調整用

# prediction = np.rint(model.predict(va_x, num_iteration=model.best_iteration))
# accuracy = accuracy_score(va_y, prediction)

# best_params = model.params
# print("Best params:", display(best_params)
# print("  Accuracy = {}".format(accuracy))
# print("  Params: ")
# for key, value in best_params.items():
#     print("    {}: {}".format(key, value))

# %%
def objective(trial):
    param = {
        'objective': 'binary',
        'metric': 'binary_logloss',
        'boosting': 'gbdt',
        'learning_rate': 0.05,
        'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
        'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
        'num_leaves': trial.suggest_int('num_leaves', 2, 512),
        'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
        'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 0, 10),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'seed': 0,
        'verbosity': -1,
    }
    gbm = lgb.train(param, 
                    lgb_train, 
                    valid_sets=lgb_eval,
                    verbose_eval=False, 
                    num_boost_round=num_round, 
                    early_stopping_rounds=100
                   )
    y_prob = gbm.predict(va_x)
    y_pred = np.round(y_prob)
    return roc_auc_score(
        np.round(va_y.values),
        np.round(y_pred)
    )

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2021-01-10 18:28:27,629] A new study created in memory with name: no-name-3f58daa7-0c06-4c53-bf0c-584c7220e26c
# [I 2021-01-10 18:28:27,632] A new study created in memory with name: no-name-1a9ca4b6-894e-4afd-bfda-9e73bc89c0e8
#
#   0%|          | 0/7 [00:00<?, ?it/s]
# feature_fraction, val_score: inf:   0%|          | 0/7 [00:00<?, ?it/s]
# feature_fraction, val_score: 0.053962:   0%|          | 0/7 [00:00<?, ?it/s]
# feature_fraction, val_score: 0.053962:  14%|#4        | 1/7 [00:00<00:01,  5.20it/s][I 2021-01-10 18:28:27,831] Trial 0 finished with value: 0.0539624985980035 and parameters: {'feature_fraction': 0.8}. Best is trial 0 with value: 0.0539624985980035.
#
# feature_fraction, val_score: 0.053962:  14%|#4        | 1/7 [00:00<00:01,  5.20it/s]
# feature_fraction, val_score: 0.053102:  14%|#4        | 1/7 [00:00<00:01,  5.20it/s]
# feature_fraction, val_score: 0.053102:  29%|##8       | 2/7 [00:00<00:00,  5.13it/s][I 2021-01-10 18:28:28,031] Trial 1 finished with value: 0.05310172046216772 and parameters: {'feature_fraction': 0.5}. Best is trial 1 with value: 0.05310172046216772.
#
# feature_fraction, val_score: 0.053102:  29%|##8       | 2/7 [00:00<00:00,  5.13it/s]
# feature_fraction, val_score: 0.053102:  29%|##8       | 2/7 [00:00<00:00,  5.13it/s]
# feature_fraction, val_score: 0.053102:  43%|####2     | 3/7 [00:00<00:00,  5.09it/s][I 2021-01-10 18:28:28,231] Trial 2 finished with value: 0.054840919012513895 and parameters: {'feature_fraction': 1.0}. Best is trial 1 with value: 0.05310172046216772.
#
# feature_fraction, val_score: 0.053102:  43%|####2     | 3/7 [00:00<00:00,  5.09it/s]
# feature_fraction, val_score: 0.053102:  43%|####2     | 3/7 [00:00<00:00,  5.09it/s]
# feature_fraction, val_score: 0.053102:  57%|#####7    | 4/7 [00:00<00:00,  5.38it/s][I 2021-01-10 18:28:28,392] Trial 3 finished with value: 0.05323445334178776 and parameters: {'feature_fraction': 0.4}. Best is trial 1 with value: 0.05310172046216772.
#
# feature_fraction, val_score: 0.053102:  57%|#####7    | 4/7 [00:00<00:00,  5.38it/s]
# feature_fraction, val_score: 0.051492:  57%|#####7    | 4/7 [00:00<00:00,  5.38it/s]
# feature_fraction, val_score: 0.051492:  71%|#######1  | 5/7 [00:00<00:00,  5.33it/s][I 2021-01-10 18:28:28,584] Trial 4 finished with value: 0.051491816235135934 and parameters: {'feature_fraction': 0.6}. Best is trial 4 with value: 0.051491816235135934.
#
# feature_fraction, val_score: 0.051492:  71%|#######1  | 5/7 [00:00<00:00,  5.33it/s]
# feature_fraction, val_score: 0.051492:  71%|#######1  | 5/7 [00:01<00:00,  5.33it/s]
# feature_fraction, val_score: 0.051492:  86%|########5 | 6/7 [00:01<00:00,  5.36it/s][I 2021-01-10 18:28:28,768] Trial 5 finished with value: 0.05389021652965272 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 4 with value: 0.051491816235135934.
#
# feature_fraction, val_score: 0.051492:  86%|########5 | 6/7 [00:01<00:00,  5.36it/s]
# feature_fraction, val_score: 0.051492:  86%|########5 | 6/7 [00:01<00:00,  5.36it/s]
# feature_fraction, val_score: 0.051492: 100%|##########| 7/7 [00:01<00:00,  5.33it/s][I 2021-01-10 18:28:28,958] Trial 6 finished with value: 0.05279248161109377 and parameters: {'feature_fraction': 0.7}. Best is trial 4 with value: 0.051491816235135934.
# feature_fraction, val_score: 0.051492: 100%|##########| 7/7 [00:01<00:00,  5.29it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
# num_leaves, val_score: 0.051492:   0%|          | 0/20 [00:00<?, ?it/s]
# num_leaves, val_score: 0.051492:   0%|          | 0/20 [00:00<?, ?it/s]
# num_leaves, val_score: 0.051492:   5%|5         | 1/20 [00:00<00:03,  4.83it/s][I 2021-01-10 18:28:29,171] Trial 7 finished with value: 0.051491816235135934 and parameters: {'num_leaves': 152}. Best is trial 7 with value: 0.051491816235135934.
#
# num_leaves, val_score: 0.051492:   5%|5         | 1/20 [00:00<00:03,  4.83it/s]
# num_leaves, val_score: 0.051492:   5%|5         | 1/20 [00:00<00:03,  4.83it/s]
# num_leaves, val_score: 0.051492:  10%|#         | 2/20 [00:00<00:03,  5.03it/s][I 2021-01-10 18:28:29,350] Trial 8 finished with value: 0.051491816235135934 and parameters: {'num_leaves': 243}. Best is trial 7 with value: 0.051491816235135934.
#
# num_leaves, val_score: 0.051492:  10%|#         | 2/20 [00:00<00:03,  5.03it/s]
# num_leaves, val_score: 0.051492:  10%|#         | 2/20 [00:00<00:03,  5.03it/s]
# num_leaves, val_score: 0.051492:  15%|#5        | 3/20 [00:00<00:03,  5.05it/s][I 2021-01-10 18:28:29,546] Trial 9 finished with value: 0.051491816235135934 and parameters: {'num_leaves': 238}. Best is trial 7 with value: 0.051491816235135934.
#
# num_leaves, val_score: 0.051492:  15%|#5        | 3/20 [00:00<00:03,  5.05it/s]
# num_leaves, val_score: 0.051492:  15%|#5        | 3/20 [00:00<00:03,  5.05it/s]
# num_leaves, val_score: 0.051492:  20%|##        | 4/20 [00:00<00:02,  5.77it/s][I 2021-01-10 18:28:29,663] Trial 10 finished with value: 0.05236511646642176 and parameters: {'num_leaves': 11}. Best is trial 7 with value: 0.051491816235135934.
#
# num_leaves, val_score: 0.051492:  20%|##        | 4/20 [00:00<00:02,  5.77it/s]
# num_leaves, val_score: 0.051492:  20%|##        | 4/20 [00:00<00:02,  5.77it/s]
# num_leaves, val_score: 0.051492:  25%|##5       | 5/20 [00:00<00:02,  5.69it/s][I 2021-01-10 18:28:29,844] Trial 11 finished with value: 0.051491816235135934 and parameters: {'num_leaves': 118}. Best is trial 7 with value: 0.051491816235135934.
#
# num_leaves, val_score: 0.051492:  25%|##5       | 5/20 [00:00<00:02,  5.69it/s]
# num_leaves, val_score: 0.051492:  25%|##5       | 5/20 [00:01<00:02,  5.69it/s]
# num_leaves, val_score: 0.051492:  30%|###       | 6/20 [00:01<00:02,  5.17it/s][I 2021-01-10 18:28:30,078] Trial 12 finished with value: 0.051491816235135934 and parameters: {'num_leaves': 139}. Best is trial 7 with value: 0.051491816235135934.
#
# num_leaves, val_score: 0.051492:  30%|###       | 6/20 [00:01<00:02,  5.17it/s]
# num_leaves, val_score: 0.051492:  30%|###       | 6/20 [00:01<00:02,  5.17it/s]
# num_leaves, val_score: 0.051492:  35%|###5      | 7/20 [00:01<00:02,  5.57it/s][I 2021-01-10 18:28:30,226] Trial 13 finished with value: 0.051491816235135934 and parameters: {'num_leaves': 139}. Best is trial 7 with value: 0.051491816235135934.
#
# num_leaves, val_score: 0.051492:  35%|###5      | 7/20 [00:01<00:02,  5.57it/s]
# num_leaves, val_score: 0.051492:  35%|###5      | 7/20 [00:01<00:02,  5.57it/s]
# num_leaves, val_score: 0.051492:  40%|####      | 8/20 [00:01<00:02,  5.69it/s][I 2021-01-10 18:28:30,392] Trial 14 finished with value: 0.051491816235135934 and parameters: {'num_leaves': 74}. Best is trial 7 with value: 0.051491816235135934.
#
# num_leaves, val_score: 0.051492:  40%|####      | 8/20 [00:01<00:02,  5.69it/s]
# num_leaves, val_score: 0.051492:  40%|####      | 8/20 [00:01<00:02,  5.69it/s]
# num_leaves, val_score: 0.051492:  45%|####5     | 9/20 [00:01<00:01,  5.51it/s][I 2021-01-10 18:28:30,587] Trial 15 finished with value: 0.051491816235135934 and parameters: {'num_leaves': 199}. Best is trial 7 with value: 0.051491816235135934.
#
# num_leaves, val_score: 0.051492:  45%|####5     | 9/20 [00:01<00:01,  5.51it/s]
# num_leaves, val_score: 0.051492:  45%|####5     | 9/20 [00:01<00:01,  5.51it/s]
# num_leaves, val_score: 0.051492:  50%|#####     | 10/20 [00:01<00:01,  5.87it/s][I 2021-01-10 18:28:30,732] Trial 16 finished with value: 0.051491816235135934 and parameters: {'num_leaves': 48}. Best is trial 7 with value: 0.051491816235135934.
#
# num_leaves, val_score: 0.051492:  50%|#####     | 10/20 [00:01<00:01,  5.87it/s]
# num_leaves, val_score: 0.051492:  50%|#####     | 10/20 [00:02<00:01,  5.87it/s]
# num_leaves, val_score: 0.051492:  55%|#####5    | 11/20 [00:02<00:01,  4.82it/s][I 2021-01-10 18:28:31,025] Trial 17 finished with value: 0.051491816235135934 and parameters: {'num_leaves': 62}. Best is trial 7 with value: 0.051491816235135934.
#
# num_leaves, val_score: 0.051492:  55%|#####5    | 11/20 [00:02<00:01,  4.82it/s]
# num_leaves, val_score: 0.051492:  55%|#####5    | 11/20 [00:02<00:01,  4.82it/s]
# num_leaves, val_score: 0.051492:  60%|######    | 12/20 [00:02<00:01,  5.17it/s][I 2021-01-10 18:28:31,187] Trial 18 finished with value: 0.051491816235135934 and parameters: {'num_leaves': 250}. Best is trial 7 with value: 0.051491816235135934.
#
# num_leaves, val_score: 0.051492:  60%|######    | 12/20 [00:02<00:01,  5.17it/s]
# num_leaves, val_score: 0.050336:  60%|######    | 12/20 [00:02<00:01,  5.17it/s][I 2021-01-10 18:28:31,238] Trial 19 finished with value: 0.05033588737910225 and parameters: {'num_leaves': 3}. Best is trial 19 with value: 0.05033588737910225.
#
# num_leaves, val_score: 0.050336:  65%|######5   | 13/20 [00:02<00:01,  5.17it/s]
# num_leaves, val_score: 0.050336:  65%|######5   | 13/20 [00:02<00:01,  5.17it/s]
# num_leaves, val_score: 0.050336:  70%|#######   | 14/20 [00:02<00:00,  6.64it/s][I 2021-01-10 18:28:31,287] Trial 20 finished with value: 0.05033588737910225 and parameters: {'num_leaves': 3}. Best is trial 19 with value: 0.05033588737910225.
#
# num_leaves, val_score: 0.050336:  70%|#######   | 14/20 [00:02<00:00,  6.64it/s]
# num_leaves, val_score: 0.050336:  70%|#######   | 14/20 [00:02<00:00,  6.64it/s][I 2021-01-10 18:28:31,357] Trial 21 finished with value: 0.05173843064467262 and parameters: {'num_leaves': 7}. Best is trial 19 with value: 0.05033588737910225.
#
# num_leaves, val_score: 0.050336:  75%|#######5  | 15/20 [00:02<00:00,  6.64it/s]
# num_leaves, val_score: 0.050336:  75%|#######5  | 15/20 [00:02<00:00,  6.64it/s]
# num_leaves, val_score: 0.050336:  80%|########  | 16/20 [00:02<00:00,  8.09it/s][I 2021-01-10 18:28:31,409] Trial 22 finished with value: 0.0510866400643198 and parameters: {'num_leaves': 4}. Best is trial 19 with value: 0.05033588737910225.
#
# num_leaves, val_score: 0.050336:  80%|########  | 16/20 [00:02<00:00,  8.09it/s]
# num_leaves, val_score: 0.050336:  80%|########  | 16/20 [00:02<00:00,  8.09it/s][I 2021-01-10 18:28:31,474] Trial 23 finished with value: 0.05173843064467262 and parameters: {'num_leaves': 7}. Best is trial 19 with value: 0.05033588737910225.
#
# num_leaves, val_score: 0.050336:  85%|########5 | 17/20 [00:02<00:00,  8.09it/s]
# num_leaves, val_score: 0.050336:  85%|########5 | 17/20 [00:02<00:00,  8.09it/s]
# num_leaves, val_score: 0.050336:  90%|######### | 18/20 [00:02<00:00,  7.10it/s][I 2021-01-10 18:28:31,770] Trial 24 finished with value: 0.052136634687160566 and parameters: {'num_leaves': 31}. Best is trial 19 with value: 0.05033588737910225.
#
# num_leaves, val_score: 0.050336:  90%|######### | 18/20 [00:02<00:00,  7.10it/s]
# num_leaves, val_score: 0.050336:  90%|######### | 18/20 [00:02<00:00,  7.10it/s]
# num_leaves, val_score: 0.050336:  95%|#########5| 19/20 [00:02<00:00,  7.24it/s][I 2021-01-10 18:28:31,902] Trial 25 finished with value: 0.052350511682606515 and parameters: {'num_leaves': 27}. Best is trial 19 with value: 0.05033588737910225.
#
# num_leaves, val_score: 0.050336:  95%|#########5| 19/20 [00:02<00:00,  7.24it/s]
# num_leaves, val_score: 0.050336:  95%|#########5| 19/20 [00:03<00:00,  7.24it/s]
# num_leaves, val_score: 0.050336: 100%|##########| 20/20 [00:03<00:00,  6.93it/s][I 2021-01-10 18:28:32,061] Trial 26 finished with value: 0.051491816235135934 and parameters: {'num_leaves': 88}. Best is trial 19 with value: 0.05033588737910225.
# num_leaves, val_score: 0.050336: 100%|##########| 20/20 [00:03<00:00,  6.45it/s]
#
#   0%|          | 0/10 [00:00<?, ?it/s]
# bagging, val_score: 0.050336:   0%|          | 0/10 [00:00<?, ?it/s]
# bagging, val_score: 0.050109:   0%|          | 0/10 [00:00<?, ?it/s][I 2021-01-10 18:28:32,126] Trial 27 finished with value: 0.05010877691382963 and parameters: {'bagging_fraction': 0.7150346175284386, 'bagging_freq': 4}. Best is trial 27 with value: 0.05010877691382963.
#
# bagging, val_score: 0.050109:  10%|#         | 1/10 [00:00<00:00, 15.93it/s]
# bagging, val_score: 0.049535:  10%|#         | 1/10 [00:00<00:01,  8.52it/s]
# bagging, val_score: 0.049535:  20%|##        | 2/10 [00:00<00:00, 16.91it/s][I 2021-01-10 18:28:32,186] Trial 28 finished with value: 0.0495346622475964 and parameters: {'bagging_fraction': 0.7127149666576619, 'bagging_freq': 4}. Best is trial 28 with value: 0.0495346622475964.
#
# bagging, val_score: 0.049535:  20%|##        | 2/10 [00:00<00:00, 16.91it/s]
# bagging, val_score: 0.049535:  20%|##        | 2/10 [00:00<00:00, 16.91it/s][I 2021-01-10 18:28:32,240] Trial 29 finished with value: 0.04973507097324137 and parameters: {'bagging_fraction': 0.7149006490505895, 'bagging_freq': 4}. Best is trial 28 with value: 0.0495346622475964.
#
# bagging, val_score: 0.049535:  30%|###       | 3/10 [00:00<00:00, 16.91it/s]
# bagging, val_score: 0.049535:  30%|###       | 3/10 [00:00<00:00, 16.91it/s]
# bagging, val_score: 0.049535:  40%|####      | 4/10 [00:00<00:00, 17.45it/s][I 2021-01-10 18:28:32,292] Trial 30 finished with value: 0.04991478184206083 and parameters: {'bagging_fraction': 0.7268402056998653, 'bagging_freq': 4}. Best is trial 28 with value: 0.0495346622475964.
#
# bagging, val_score: 0.049535:  40%|####      | 4/10 [00:00<00:00, 17.45it/s]
# bagging, val_score: 0.049535:  40%|####      | 4/10 [00:00<00:00, 17.45it/s][I 2021-01-10 18:28:32,351] Trial 31 finished with value: 0.04988799586139274 and parameters: {'bagging_fraction': 0.7286488140621327, 'bagging_freq': 4}. Best is trial 28 with value: 0.0495346622475964.
#
# bagging, val_score: 0.049535:  50%|#####     | 5/10 [00:00<00:00, 17.45it/s]
# bagging, val_score: 0.049535:  50%|#####     | 5/10 [00:00<00:00, 17.45it/s]
# bagging, val_score: 0.049535:  60%|######    | 6/10 [00:00<00:00, 16.68it/s][I 2021-01-10 18:28:32,424] Trial 32 finished with value: 0.0495964759972461 and parameters: {'bagging_fraction': 0.7212796482402233, 'bagging_freq': 4}. Best is trial 28 with value: 0.0495346622475964.
#
# bagging, val_score: 0.049535:  60%|######    | 6/10 [00:00<00:00, 16.68it/s]
# bagging, val_score: 0.049535:  60%|######    | 6/10 [00:00<00:00, 16.68it/s][I 2021-01-10 18:28:32,481] Trial 33 finished with value: 0.0495346622475964 and parameters: {'bagging_fraction': 0.7125803393695056, 'bagging_freq': 4}. Best is trial 28 with value: 0.0495346622475964.
#
# bagging, val_score: 0.049535:  70%|#######   | 7/10 [00:00<00:00, 16.68it/s]
# bagging, val_score: 0.049157:  70%|#######   | 7/10 [00:00<00:00, 16.68it/s]
# bagging, val_score: 0.049157:  80%|########  | 8/10 [00:00<00:00, 17.03it/s][I 2021-01-10 18:28:32,536] Trial 34 finished with value: 0.04915733872785969 and parameters: {'bagging_fraction': 0.6993205892332418, 'bagging_freq': 4}. Best is trial 34 with value: 0.04915733872785969.
#
# bagging, val_score: 0.049157:  80%|########  | 8/10 [00:00<00:00, 17.03it/s]
# bagging, val_score: 0.049157:  80%|########  | 8/10 [00:00<00:00, 17.03it/s][I 2021-01-10 18:28:32,589] Trial 35 finished with value: 0.04964270001702671 and parameters: {'bagging_fraction': 0.5186227312734779, 'bagging_freq': 3}. Best is trial 34 with value: 0.04915733872785969.
#
# bagging, val_score: 0.049157:  90%|######### | 9/10 [00:00<00:00, 17.03it/s]
# bagging, val_score: 0.048472:  90%|######### | 9/10 [00:00<00:00, 17.03it/s]
# bagging, val_score: 0.048472: 100%|##########| 10/10 [00:00<00:00, 14.61it/s][I 2021-01-10 18:28:32,718] Trial 36 finished with value: 0.04847219391252042 and parameters: {'bagging_fraction': 0.8919166225111922, 'bagging_freq': 7}. Best is trial 36 with value: 0.04847219391252042.
# bagging, val_score: 0.048472: 100%|##########| 10/10 [00:00<00:00, 15.29it/s]
#
#   0%|          | 0/6 [00:00<?, ?it/s]
# feature_fraction_stage2, val_score: 0.048472:   0%|          | 0/6 [00:00<?, ?it/s]
# feature_fraction_stage2, val_score: 0.048345:   0%|          | 0/6 [00:00<?, ?it/s][I 2021-01-10 18:28:32,791] Trial 37 finished with value: 0.048344731827995875 and parameters: {'feature_fraction': 0.52}. Best is trial 37 with value: 0.048344731827995875.
#
# feature_fraction_stage2, val_score: 0.048345:  17%|#6        | 1/6 [00:00<00:00, 13.70it/s]
# feature_fraction_stage2, val_score: 0.048345:  17%|#6        | 1/6 [00:00<00:00,  7.78it/s]
# feature_fraction_stage2, val_score: 0.048345:  33%|###3      | 2/6 [00:00<00:00, 15.41it/s][I 2021-01-10 18:28:32,855] Trial 38 finished with value: 0.048344731827995875 and parameters: {'feature_fraction': 0.552}. Best is trial 37 with value: 0.048344731827995875.
#
# feature_fraction_stage2, val_score: 0.048345:  33%|###3      | 2/6 [00:00<00:00, 15.41it/s]
# feature_fraction_stage2, val_score: 0.048345:  33%|###3      | 2/6 [00:00<00:00, 15.41it/s][I 2021-01-10 18:28:32,918] Trial 39 finished with value: 0.04870262491495985 and parameters: {'feature_fraction': 0.6479999999999999}. Best is trial 37 with value: 0.048344731827995875.
#
# feature_fraction_stage2, val_score: 0.048345:  50%|#####     | 3/6 [00:00<00:00, 15.41it/s]
# feature_fraction_stage2, val_score: 0.048345:  50%|#####     | 3/6 [00:00<00:00, 15.41it/s]
# feature_fraction_stage2, val_score: 0.048345:  67%|######6   | 4/6 [00:00<00:00, 15.29it/s][I 2021-01-10 18:28:32,988] Trial 40 finished with value: 0.04847219391252042 and parameters: {'feature_fraction': 0.584}. Best is trial 37 with value: 0.048344731827995875.
#
# feature_fraction_stage2, val_score: 0.048345:  67%|######6   | 4/6 [00:00<00:00, 15.29it/s]
# feature_fraction_stage2, val_score: 0.048278:  67%|######6   | 4/6 [00:00<00:00, 15.29it/s][I 2021-01-10 18:28:33,060] Trial 41 finished with value: 0.04827755842868617 and parameters: {'feature_fraction': 0.6799999999999999}. Best is trial 41 with value: 0.04827755842868617.
#
# feature_fraction_stage2, val_score: 0.048278:  83%|########3 | 5/6 [00:00<00:00, 15.29it/s]
# feature_fraction_stage2, val_score: 0.048278:  83%|########3 | 5/6 [00:00<00:00, 15.29it/s]
# feature_fraction_stage2, val_score: 0.048278: 100%|##########| 6/6 [00:00<00:00, 15.22it/s][I 2021-01-10 18:28:33,121] Trial 42 finished with value: 0.04870262491495985 and parameters: {'feature_fraction': 0.616}. Best is trial 41 with value: 0.04827755842868617.
# feature_fraction_stage2, val_score: 0.048278: 100%|##########| 6/6 [00:00<00:00, 15.02it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
# regularization_factors, val_score: 0.048278:   0%|          | 0/20 [00:00<?, ?it/s]
# regularization_factors, val_score: 0.048278:   0%|          | 0/20 [00:00<?, ?it/s][I 2021-01-10 18:28:33,216] Trial 43 finished with value: 0.04855016078687165 and parameters: {'lambda_l1': 1.6103003947311514e-06, 'lambda_l2': 1.4770541974079167e-05}. Best is trial 43 with value: 0.04855016078687165.
#
# regularization_factors, val_score: 0.048278:   5%|5         | 1/20 [00:00<00:01, 10.93it/s]
# regularization_factors, val_score: 0.048278:   5%|5         | 1/20 [00:00<00:02,  6.56it/s]
# regularization_factors, val_score: 0.048278:  10%|#         | 2/20 [00:00<00:01, 13.04it/s][I 2021-01-10 18:28:33,282] Trial 44 finished with value: 0.05334740071230895 and parameters: {'lambda_l1': 9.377000291587548, 'lambda_l2': 8.159379834538282}. Best is trial 43 with value: 0.04855016078687165.
#
# regularization_factors, val_score: 0.048278:  10%|#         | 2/20 [00:00<00:01, 13.04it/s]
# regularization_factors, val_score: 0.048278:  10%|#         | 2/20 [00:00<00:01, 13.04it/s][I 2021-01-10 18:28:33,342] Trial 45 finished with value: 0.048511612817376426 and parameters: {'lambda_l1': 0.5700788658158673, 'lambda_l2': 1.0736662234621274e-08}. Best is trial 45 with value: 0.048511612817376426.
#
# regularization_factors, val_score: 0.048278:  15%|#5        | 3/20 [00:00<00:01, 13.04it/s]
# regularization_factors, val_score: 0.048278:  15%|#5        | 3/20 [00:00<00:01, 13.04it/s]
# regularization_factors, val_score: 0.048278:  20%|##        | 4/20 [00:00<00:01, 13.96it/s][I 2021-01-10 18:28:33,401] Trial 46 finished with value: 0.048717210545127336 and parameters: {'lambda_l1': 1.1838677772823528e-08, 'lambda_l2': 0.875081313482876}. Best is trial 45 with value: 0.048511612817376426.
#
# regularization_factors, val_score: 0.048278:  20%|##        | 4/20 [00:00<00:01, 13.96it/s]
# regularization_factors, val_score: 0.048278:  20%|##        | 4/20 [00:00<00:01, 13.96it/s][I 2021-01-10 18:28:33,464] Trial 47 finished with value: 0.04845041775793265 and parameters: {'lambda_l1': 0.004812952511165797, 'lambda_l2': 0.00023322563194525507}. Best is trial 47 with value: 0.04845041775793265.
#
# regularization_factors, val_score: 0.048278:  25%|##5       | 5/20 [00:00<00:01, 13.96it/s]
# regularization_factors, val_score: 0.048278:  25%|##5       | 5/20 [00:00<00:01, 13.96it/s]
# regularization_factors, val_score: 0.048278:  30%|###       | 6/20 [00:00<00:00, 14.52it/s][I 2021-01-10 18:28:33,527] Trial 48 finished with value: 0.048450812227299675 and parameters: {'lambda_l1': 0.0025884264485152007, 'lambda_l2': 0.000560583128070689}. Best is trial 47 with value: 0.04845041775793265.
#
# regularization_factors, val_score: 0.048278:  30%|###       | 6/20 [00:00<00:00, 14.52it/s]
# regularization_factors, val_score: 0.048278:  30%|###       | 6/20 [00:00<00:00, 14.52it/s][I 2021-01-10 18:28:33,604] Trial 49 finished with value: 0.04845064318025701 and parameters: {'lambda_l1': 0.0036642891538392498, 'lambda_l2': 0.000388270136744894}. Best is trial 47 with value: 0.04845041775793265.
#
# regularization_factors, val_score: 0.048278:  35%|###5      | 7/20 [00:00<00:00, 14.52it/s]
# regularization_factors, val_score: 0.048278:  35%|###5      | 7/20 [00:00<00:00, 14.52it/s]
# regularization_factors, val_score: 0.048278:  40%|####      | 8/20 [00:00<00:00, 12.47it/s][I 2021-01-10 18:28:33,740] Trial 50 finished with value: 0.04845107416699233 and parameters: {'lambda_l1': 0.0030232511374613173, 'lambda_l2': 0.0002798253034470099}. Best is trial 47 with value: 0.04845041775793265.
#
# regularization_factors, val_score: 0.048278:  40%|####      | 8/20 [00:00<00:00, 12.47it/s]
# regularization_factors, val_score: 0.048278:  40%|####      | 8/20 [00:00<00:00, 12.47it/s][I 2021-01-10 18:28:33,817] Trial 51 finished with value: 0.04881339120626885 and parameters: {'lambda_l1': 0.0036830913654047016, 'lambda_l2': 0.003759898416425467}. Best is trial 47 with value: 0.04845041775793265.
#
# regularization_factors, val_score: 0.048278:  45%|####5     | 9/20 [00:00<00:00, 12.47it/s]
# regularization_factors, val_score: 0.048278:  45%|####5     | 9/20 [00:00<00:00, 12.47it/s]
# regularization_factors, val_score: 0.048278:  50%|#####     | 10/20 [00:00<00:00, 11.96it/s][I 2021-01-10 18:28:33,923] Trial 52 finished with value: 0.04845237807331496 and parameters: {'lambda_l1': 0.0006469074223568132, 'lambda_l2': 6.911196428466101e-05}. Best is trial 47 with value: 0.04845041775793265.
#
# regularization_factors, val_score: 0.048278:  50%|#####     | 10/20 [00:00<00:00, 11.96it/s]
# regularization_factors, val_score: 0.048278:  50%|#####     | 10/20 [00:00<00:00, 11.96it/s][I 2021-01-10 18:28:33,987] Trial 53 finished with value: 0.04856498073420058 and parameters: {'lambda_l1': 0.03831133858542851, 'lambda_l2': 0.010645430181524458}. Best is trial 47 with value: 0.04845041775793265.
#
# regularization_factors, val_score: 0.048278:  55%|#####5    | 11/20 [00:00<00:00, 11.96it/s]
# regularization_factors, val_score: 0.048278:  55%|#####5    | 11/20 [00:00<00:00, 11.96it/s]
# regularization_factors, val_score: 0.048278:  60%|######    | 12/20 [00:00<00:00, 12.82it/s][I 2021-01-10 18:28:34,053] Trial 54 finished with value: 0.04855018018841403 and parameters: {'lambda_l1': 3.7549478864555535e-05, 'lambda_l2': 3.5984235477363637e-07}. Best is trial 47 with value: 0.04845041775793265.
#
# regularization_factors, val_score: 0.048278:  60%|######    | 12/20 [00:00<00:00, 12.82it/s]
# regularization_factors, val_score: 0.048278:  60%|######    | 12/20 [00:00<00:00, 12.82it/s][I 2021-01-10 18:28:34,118] Trial 55 finished with value: 0.048492146639381194 and parameters: {'lambda_l1': 0.08354061286805063, 'lambda_l2': 0.014050204902750075}. Best is trial 47 with value: 0.04845041775793265.
#
# regularization_factors, val_score: 0.048278:  65%|######5   | 13/20 [00:00<00:00, 12.82it/s]
# regularization_factors, val_score: 0.048278:  65%|######5   | 13/20 [00:01<00:00, 12.82it/s]
# regularization_factors, val_score: 0.048278:  70%|#######   | 14/20 [00:01<00:00, 13.65it/s][I 2021-01-10 18:28:34,177] Trial 56 finished with value: 0.04855014313306488 and parameters: {'lambda_l1': 0.00011074843031987688, 'lambda_l2': 1.1335675881378698e-06}. Best is trial 47 with value: 0.04845041775793265.
#
# regularization_factors, val_score: 0.048278:  70%|#######   | 14/20 [00:01<00:00, 13.65it/s]
# regularization_factors, val_score: 0.048278:  70%|#######   | 14/20 [00:01<00:00, 13.65it/s][I 2021-01-10 18:28:34,261] Trial 57 finished with value: 0.04875554671923186 and parameters: {'lambda_l1': 0.015236617937272658, 'lambda_l2': 0.0014169600687339795}. Best is trial 47 with value: 0.04845041775793265.
#
# regularization_factors, val_score: 0.048278:  75%|#######5  | 15/20 [00:01<00:00, 13.65it/s]
# regularization_factors, val_score: 0.048278:  75%|#######5  | 15/20 [00:01<00:00, 13.65it/s]
# regularization_factors, val_score: 0.048278:  80%|########  | 16/20 [00:01<00:00, 13.52it/s][I 2021-01-10 18:28:34,328] Trial 58 finished with value: 0.04885588980223583 and parameters: {'lambda_l1': 1.1465301110026013e-05, 'lambda_l2': 0.08594096951536993}. Best is trial 47 with value: 0.04845041775793265.
#
# regularization_factors, val_score: 0.048278:  80%|########  | 16/20 [00:01<00:00, 13.52it/s]
# regularization_factors, val_score: 0.048278:  80%|########  | 16/20 [00:01<00:00, 13.52it/s][I 2021-01-10 18:28:34,394] Trial 59 finished with value: 0.048576243618628424 and parameters: {'lambda_l1': 0.8711614254999256, 'lambda_l2': 8.644313936663418e-06}. Best is trial 47 with value: 0.04845041775793265.
#
# regularization_factors, val_score: 0.048278:  85%|########5 | 17/20 [00:01<00:00, 13.52it/s]
# regularization_factors, val_score: 0.048278:  85%|########5 | 17/20 [00:01<00:00, 13.52it/s]
# regularization_factors, val_score: 0.048278:  90%|######### | 18/20 [00:01<00:00, 13.93it/s][I 2021-01-10 18:28:34,462] Trial 60 finished with value: 0.04845174427888684 and parameters: {'lambda_l1': 0.0015223794787285426, 'lambda_l2': 0.00024315789486037984}. Best is trial 47 with value: 0.04845041775793265.
#
# regularization_factors, val_score: 0.048278:  90%|######### | 18/20 [00:01<00:00, 13.93it/s]
# regularization_factors, val_score: 0.048278:  90%|######### | 18/20 [00:01<00:00, 13.93it/s][I 2021-01-10 18:28:34,531] Trial 61 finished with value: 0.048450074033797176 and parameters: {'lambda_l1': 0.00516500818528997, 'lambda_l2': 0.0003616382148389023}. Best is trial 61 with value: 0.048450074033797176.
#
# regularization_factors, val_score: 0.048278:  95%|#########5| 19/20 [00:01<00:00, 13.93it/s]
# regularization_factors, val_score: 0.048278:  95%|#########5| 19/20 [00:01<00:00, 13.93it/s]
# regularization_factors, val_score: 0.048278: 100%|##########| 20/20 [00:01<00:00, 14.30it/s][I 2021-01-10 18:28:34,593] Trial 62 finished with value: 0.04845103940895125 and parameters: {'lambda_l1': 0.0003948510214324213, 'lambda_l2': 0.0009885909524089515}. Best is trial 61 with value: 0.048450074033797176.
# regularization_factors, val_score: 0.048278: 100%|##########| 20/20 [00:01<00:00, 13.62it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# min_data_in_leaf, val_score: 0.048278:   0%|          | 0/5 [00:00<?, ?it/s]
# min_data_in_leaf, val_score: 0.048278:   0%|          | 0/5 [00:00<?, ?it/s][I 2021-01-10 18:28:34,667] Trial 63 finished with value: 0.04827755842868617 and parameters: {'min_child_samples': 100}. Best is trial 63 with value: 0.04827755842868617.
#
# min_data_in_leaf, val_score: 0.048278:  20%|##        | 1/5 [00:00<00:00, 12.98it/s]
# min_data_in_leaf, val_score: 0.048278:  20%|##        | 1/5 [00:00<00:00,  7.82it/s]
# min_data_in_leaf, val_score: 0.048278:  40%|####      | 2/5 [00:00<00:00, 15.49it/s][I 2021-01-10 18:28:34,728] Trial 64 finished with value: 0.04827755842868617 and parameters: {'min_child_samples': 50}. Best is trial 63 with value: 0.04827755842868617.
#
# min_data_in_leaf, val_score: 0.048278:  40%|####      | 2/5 [00:00<00:00, 15.49it/s]
# min_data_in_leaf, val_score: 0.048278:  40%|####      | 2/5 [00:00<00:00, 15.49it/s][I 2021-01-10 18:28:34,794] Trial 65 finished with value: 0.04827755842868617 and parameters: {'min_child_samples': 10}. Best is trial 63 with value: 0.04827755842868617.
#
# min_data_in_leaf, val_score: 0.048278:  60%|######    | 3/5 [00:00<00:00, 15.49it/s]
# min_data_in_leaf, val_score: 0.048278:  60%|######    | 3/5 [00:00<00:00, 15.49it/s]
# min_data_in_leaf, val_score: 0.048278:  80%|########  | 4/5 [00:00<00:00, 15.35it/s][I 2021-01-10 18:28:34,861] Trial 66 finished with value: 0.04827755842868617 and parameters: {'min_child_samples': 5}. Best is trial 63 with value: 0.04827755842868617.
#
# min_data_in_leaf, val_score: 0.048278:  80%|########  | 4/5 [00:00<00:00, 15.35it/s]
# min_data_in_leaf, val_score: 0.048278:  80%|########  | 4/5 [00:00<00:00, 15.35it/s][I 2021-01-10 18:28:34,924] Trial 67 finished with value: 0.04827755842868617 and parameters: {'min_child_samples': 25}. Best is trial 63 with value: 0.04827755842868617.
# min_data_in_leaf, val_score: 0.048278: 100%|##########| 5/5 [00:00<00:00, 15.21it/s]
# [I 2021-01-10 18:28:34,934] Trial 0 finished with value: 0.5 and parameters: {'lambda_l1': 2.0287767534943125e-05, 'lambda_l2': 0.08313105120635257, 'num_leaves': 366, 'feature_fraction': 0.52087314268286, 'bagging_fraction': 0.7485611416114903, 'bagging_freq': 0, 'min_child_samples': 11}. Best is trial 0 with value: 0.5.
# [I 2021-01-10 18:28:34,935] A new study created in memory with name: no-name-4def36b9-3b42-4586-9962-90a0910aaeeb
#
#   0%|          | 0/7 [00:00<?, ?it/s]
# feature_fraction, val_score: inf:   0%|          | 0/7 [00:00<?, ?it/s]
# feature_fraction, val_score: 0.050481:   0%|          | 0/7 [00:00<?, ?it/s]
# feature_fraction, val_score: 0.050481:  14%|#4        | 1/7 [00:00<00:00,  8.54it/s][I 2021-01-10 18:28:35,059] Trial 0 finished with value: 0.05048105923514451 and parameters: {'feature_fraction': 0.8}. Best is trial 0 with value: 0.05048105923514451.
#
# feature_fraction, val_score: 0.050481:  14%|#4        | 1/7 [00:00<00:00,  8.54it/s]
# feature_fraction, val_score: 0.050481:  14%|#4        | 1/7 [00:00<00:00,  8.54it/s][I 2021-01-10 18:28:35,139] Trial 1 finished with value: 0.05155336450021199 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 0 with value: 0.05048105923514451.
#
# feature_fraction, val_score: 0.050481:  29%|##8       | 2/7 [00:00<00:00,  8.54it/s]
# feature_fraction, val_score: 0.050481:  29%|##8       | 2/7 [00:00<00:00,  8.54it/s]
# feature_fraction, val_score: 0.050481:  43%|####2     | 3/7 [00:00<00:00,  9.38it/s][I 2021-01-10 18:28:35,223] Trial 2 finished with value: 0.05052659406058656 and parameters: {'feature_fraction': 0.7}. Best is trial 0 with value: 0.05048105923514451.
#
# feature_fraction, val_score: 0.050481:  43%|####2     | 3/7 [00:00<00:00,  9.38it/s]
# feature_fraction, val_score: 0.050481:  43%|####2     | 3/7 [00:00<00:00,  9.38it/s][I 2021-01-10 18:28:35,315] Trial 3 finished with value: 0.05063719692204769 and parameters: {'feature_fraction': 1.0}. Best is trial 0 with value: 0.05048105923514451.
#
# feature_fraction, val_score: 0.050481:  57%|#####7    | 4/7 [00:00<00:00,  9.38it/s]
# feature_fraction, val_score: 0.050481:  57%|#####7    | 4/7 [00:00<00:00,  9.38it/s]
# feature_fraction, val_score: 0.050481:  71%|#######1  | 5/7 [00:00<00:00,  9.90it/s][I 2021-01-10 18:28:35,399] Trial 4 finished with value: 0.05144090548525518 and parameters: {'feature_fraction': 0.5}. Best is trial 0 with value: 0.05048105923514451.
#
# feature_fraction, val_score: 0.050481:  71%|#######1  | 5/7 [00:00<00:00,  9.90it/s]
# feature_fraction, val_score: 0.050481:  71%|#######1  | 5/7 [00:00<00:00,  9.90it/s][I 2021-01-10 18:28:35,481] Trial 5 finished with value: 0.05147862280393149 and parameters: {'feature_fraction': 0.4}. Best is trial 0 with value: 0.05048105923514451.
#
# feature_fraction, val_score: 0.050481:  86%|########5 | 6/7 [00:00<00:00,  9.90it/s]
# feature_fraction, val_score: 0.050299:  86%|########5 | 6/7 [00:00<00:00,  9.90it/s]
# feature_fraction, val_score: 0.050299: 100%|##########| 7/7 [00:00<00:00, 10.58it/s][I 2021-01-10 18:28:35,558] Trial 6 finished with value: 0.05029944815190357 and parameters: {'feature_fraction': 0.6}. Best is trial 6 with value: 0.05029944815190357.
# feature_fraction, val_score: 0.050299: 100%|##########| 7/7 [00:00<00:00, 11.30it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
# num_leaves, val_score: 0.050299:   0%|          | 0/20 [00:00<?, ?it/s]
# num_leaves, val_score: 0.050299:   0%|          | 0/20 [00:00<?, ?it/s][I 2021-01-10 18:28:35,641] Trial 7 finished with value: 0.05062739703806632 and parameters: {'num_leaves': 6}. Best is trial 7 with value: 0.05062739703806632.
#
# num_leaves, val_score: 0.050299:   5%|5         | 1/20 [00:00<00:01, 12.44it/s]
# num_leaves, val_score: 0.050299:   5%|5         | 1/20 [00:00<00:02,  6.37it/s]
# num_leaves, val_score: 0.050299:  10%|#         | 2/20 [00:00<00:01, 12.67it/s][I 2021-01-10 18:28:35,722] Trial 8 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 162}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  10%|#         | 2/20 [00:00<00:01, 12.67it/s]
# num_leaves, val_score: 0.050299:  10%|#         | 2/20 [00:00<00:01, 12.67it/s][I 2021-01-10 18:28:35,805] Trial 9 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 220}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  15%|#5        | 3/20 [00:00<00:01, 12.67it/s]
# num_leaves, val_score: 0.050299:  15%|#5        | 3/20 [00:00<00:01, 12.67it/s]
# num_leaves, val_score: 0.050299:  20%|##        | 4/20 [00:00<00:01, 12.75it/s][I 2021-01-10 18:28:35,877] Trial 10 finished with value: 0.05030168998372455 and parameters: {'num_leaves': 12}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  20%|##        | 4/20 [00:00<00:01, 12.75it/s]
# num_leaves, val_score: 0.050299:  20%|##        | 4/20 [00:00<00:01, 12.75it/s][I 2021-01-10 18:28:35,959] Trial 11 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 159}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  25%|##5       | 5/20 [00:00<00:01, 12.75it/s]
# num_leaves, val_score: 0.050299:  25%|##5       | 5/20 [00:00<00:01, 12.75it/s]
# num_leaves, val_score: 0.050299:  30%|###       | 6/20 [00:00<00:01, 12.04it/s][I 2021-01-10 18:28:36,065] Trial 12 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 129}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  30%|###       | 6/20 [00:00<00:01, 12.04it/s]
# num_leaves, val_score: 0.050299:  30%|###       | 6/20 [00:00<00:01, 12.04it/s]
# num_leaves, val_score: 0.050299:  35%|###5      | 7/20 [00:00<00:01, 10.26it/s][I 2021-01-10 18:28:36,196] Trial 13 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 209}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  35%|###5      | 7/20 [00:00<00:01, 10.26it/s]
# num_leaves, val_score: 0.050299:  35%|###5      | 7/20 [00:00<00:01, 10.26it/s][I 2021-01-10 18:28:36,280] Trial 14 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 67}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  40%|####      | 8/20 [00:00<00:01, 10.26it/s]
# num_leaves, val_score: 0.050299:  40%|####      | 8/20 [00:00<00:01, 10.26it/s]
# num_leaves, val_score: 0.050299:  45%|####5     | 9/20 [00:00<00:01, 10.73it/s][I 2021-01-10 18:28:36,362] Trial 15 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 174}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  45%|####5     | 9/20 [00:00<00:01, 10.73it/s]
# num_leaves, val_score: 0.050299:  45%|####5     | 9/20 [00:00<00:01, 10.73it/s][I 2021-01-10 18:28:36,452] Trial 16 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 78}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  50%|#####     | 10/20 [00:00<00:00, 10.73it/s]
# num_leaves, val_score: 0.050299:  50%|#####     | 10/20 [00:00<00:00, 10.73it/s]
# num_leaves, val_score: 0.050299:  55%|#####5    | 11/20 [00:00<00:00, 11.09it/s][I 2021-01-10 18:28:36,528] Trial 17 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 75}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  55%|#####5    | 11/20 [00:00<00:00, 11.09it/s]
# num_leaves, val_score: 0.050299:  55%|#####5    | 11/20 [00:01<00:00, 11.09it/s][I 2021-01-10 18:28:36,625] Trial 18 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 182}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  60%|######    | 12/20 [00:01<00:00, 11.09it/s]
# num_leaves, val_score: 0.050299:  60%|######    | 12/20 [00:01<00:00, 11.09it/s]
# num_leaves, val_score: 0.050299:  65%|######5   | 13/20 [00:01<00:00, 11.00it/s][I 2021-01-10 18:28:36,714] Trial 19 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 256}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  65%|######5   | 13/20 [00:01<00:00, 11.00it/s]
# num_leaves, val_score: 0.050299:  65%|######5   | 13/20 [00:01<00:00, 11.00it/s][I 2021-01-10 18:28:36,819] Trial 20 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 72}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  70%|#######   | 14/20 [00:01<00:00, 11.00it/s]
# num_leaves, val_score: 0.050299:  70%|#######   | 14/20 [00:01<00:00, 11.00it/s]
# num_leaves, val_score: 0.050299:  75%|#######5  | 15/20 [00:01<00:00, 10.99it/s][I 2021-01-10 18:28:36,896] Trial 21 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 61}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  75%|#######5  | 15/20 [00:01<00:00, 10.99it/s]
# num_leaves, val_score: 0.050299:  75%|#######5  | 15/20 [00:01<00:00, 10.99it/s][I 2021-01-10 18:28:36,984] Trial 22 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 230}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  80%|########  | 16/20 [00:01<00:00, 10.99it/s]
# num_leaves, val_score: 0.050299:  80%|########  | 16/20 [00:01<00:00, 10.99it/s]
# num_leaves, val_score: 0.050299:  85%|########5 | 17/20 [00:01<00:00, 11.16it/s][I 2021-01-10 18:28:37,069] Trial 23 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 110}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  85%|########5 | 17/20 [00:01<00:00, 11.16it/s]
# num_leaves, val_score: 0.050299:  85%|########5 | 17/20 [00:01<00:00, 11.16it/s][I 2021-01-10 18:28:37,155] Trial 24 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 32}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  90%|######### | 18/20 [00:01<00:00, 11.16it/s]
# num_leaves, val_score: 0.050299:  90%|######### | 18/20 [00:01<00:00, 11.16it/s]
# num_leaves, val_score: 0.050299:  95%|#########5| 19/20 [00:01<00:00, 11.43it/s][I 2021-01-10 18:28:37,234] Trial 25 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 115}. Best is trial 8 with value: 0.05029944815190357.
#
# num_leaves, val_score: 0.050299:  95%|#########5| 19/20 [00:01<00:00, 11.43it/s]
# num_leaves, val_score: 0.050299:  95%|#########5| 19/20 [00:01<00:00, 11.43it/s][I 2021-01-10 18:28:37,317] Trial 26 finished with value: 0.05029944815190357 and parameters: {'num_leaves': 120}. Best is trial 8 with value: 0.05029944815190357.
# num_leaves, val_score: 0.050299: 100%|##########| 20/20 [00:01<00:00, 11.39it/s]
#
#   0%|          | 0/10 [00:00<?, ?it/s]
# bagging, val_score: 0.050299:   0%|          | 0/10 [00:00<?, ?it/s]
# bagging, val_score: 0.050299:   0%|          | 0/10 [00:00<?, ?it/s][I 2021-01-10 18:28:37,413] Trial 27 finished with value: 0.05081174220199085 and parameters: {'bagging_fraction': 0.4610531002516968, 'bagging_freq': 4}. Best is trial 27 with value: 0.05081174220199085.
#
# bagging, val_score: 0.050299:  10%|#         | 1/10 [00:00<00:00, 10.74it/s]
# bagging, val_score: 0.050299:  10%|#         | 1/10 [00:00<00:02,  3.58it/s]
# bagging, val_score: 0.050299:  20%|##        | 2/10 [00:00<00:01,  7.13it/s][I 2021-01-10 18:28:37,604] Trial 28 finished with value: 0.05118859210366434 and parameters: {'bagging_fraction': 0.993711809174824, 'bagging_freq': 1}. Best is trial 27 with value: 0.05081174220199085.
#
# bagging, val_score: 0.050299:  20%|##        | 2/10 [00:00<00:01,  7.13it/s]
# bagging, val_score: 0.050299:  20%|##        | 2/10 [00:00<00:01,  7.13it/s]
# bagging, val_score: 0.050299:  30%|###       | 3/10 [00:00<00:01,  6.52it/s][I 2021-01-10 18:28:37,789] Trial 29 finished with value: 0.05051919639716029 and parameters: {'bagging_fraction': 0.9976268918104382, 'bagging_freq': 7}. Best is trial 29 with value: 0.05051919639716029.
#
# bagging, val_score: 0.050299:  30%|###       | 3/10 [00:00<00:01,  6.52it/s]
# bagging, val_score: 0.050299:  30%|###       | 3/10 [00:00<00:01,  6.52it/s]
# bagging, val_score: 0.050299:  40%|####      | 4/10 [00:00<00:00,  7.27it/s][I 2021-01-10 18:28:37,889] Trial 30 finished with value: 0.05314091381046744 and parameters: {'bagging_fraction': 0.6707883822758582, 'bagging_freq': 7}. Best is trial 29 with value: 0.05051919639716029.
#
# bagging, val_score: 0.050299:  40%|####      | 4/10 [00:00<00:00,  7.27it/s]
# bagging, val_score: 0.049390:  40%|####      | 4/10 [00:00<00:00,  7.27it/s][I 2021-01-10 18:28:37,978] Trial 31 finished with value: 0.04938953154068988 and parameters: {'bagging_fraction': 0.4122569631800826, 'bagging_freq': 1}. Best is trial 31 with value: 0.04938953154068988.
#
# bagging, val_score: 0.049390:  50%|#####     | 5/10 [00:00<00:00,  7.27it/s]
# bagging, val_score: 0.049390:  50%|#####     | 5/10 [00:00<00:00,  7.27it/s]
# bagging, val_score: 0.049390:  60%|######    | 6/10 [00:00<00:00,  8.06it/s][I 2021-01-10 18:28:38,075] Trial 32 finished with value: 0.049927807167828374 and parameters: {'bagging_fraction': 0.42080104927183065, 'bagging_freq': 1}. Best is trial 31 with value: 0.04938953154068988.
#
# bagging, val_score: 0.049390:  60%|######    | 6/10 [00:00<00:00,  8.06it/s]
# bagging, val_score: 0.049390:  60%|######    | 6/10 [00:00<00:00,  8.06it/s][I 2021-01-10 18:28:38,166] Trial 33 finished with value: 0.0505061914049563 and parameters: {'bagging_fraction': 0.4007857322043993, 'bagging_freq': 1}. Best is trial 31 with value: 0.04938953154068988.
#
# bagging, val_score: 0.049390:  70%|#######   | 7/10 [00:00<00:00,  8.06it/s]
# bagging, val_score: 0.049390:  70%|#######   | 7/10 [00:00<00:00,  8.06it/s]
# bagging, val_score: 0.049390:  80%|########  | 8/10 [00:00<00:00,  8.70it/s][I 2021-01-10 18:28:38,262] Trial 34 finished with value: 0.05226303878661824 and parameters: {'bagging_fraction': 0.5429719332712035, 'bagging_freq': 3}. Best is trial 31 with value: 0.04938953154068988.
#
# bagging, val_score: 0.049390:  80%|########  | 8/10 [00:00<00:00,  8.70it/s]
# bagging, val_score: 0.049390:  80%|########  | 8/10 [00:01<00:00,  8.70it/s]
# bagging, val_score: 0.049390:  90%|######### | 9/10 [00:01<00:00,  8.43it/s][I 2021-01-10 18:28:38,389] Trial 35 finished with value: 0.04968429180416073 and parameters: {'bagging_fraction': 0.4001293922906447, 'bagging_freq': 2}. Best is trial 31 with value: 0.04938953154068988.
#
# bagging, val_score: 0.049390:  90%|######### | 9/10 [00:01<00:00,  8.43it/s]
# bagging, val_score: 0.049390:  90%|######### | 9/10 [00:01<00:00,  8.43it/s][I 2021-01-10 18:28:38,483] Trial 36 finished with value: 0.0502442429832789 and parameters: {'bagging_fraction': 0.4146778374359532, 'bagging_freq': 2}. Best is trial 31 with value: 0.04938953154068988.
# bagging, val_score: 0.049390: 100%|##########| 10/10 [00:01<00:00,  8.60it/s]
#
#   0%|          | 0/6 [00:00<?, ?it/s]
# feature_fraction_stage2, val_score: 0.049390:   0%|          | 0/6 [00:00<?, ?it/s]
# feature_fraction_stage2, val_score: 0.048724:   0%|          | 0/6 [00:00<?, ?it/s]
# feature_fraction_stage2, val_score: 0.048724:  17%|#6        | 1/6 [00:00<00:00,  7.78it/s][I 2021-01-10 18:28:38,618] Trial 37 finished with value: 0.04872406938298596 and parameters: {'feature_fraction': 0.552}. Best is trial 37 with value: 0.04872406938298596.
#
# feature_fraction_stage2, val_score: 0.048724:  17%|#6        | 1/6 [00:00<00:00,  7.78it/s]
# feature_fraction_stage2, val_score: 0.048724:  17%|#6        | 1/6 [00:00<00:00,  7.78it/s]
# feature_fraction_stage2, val_score: 0.048724:  33%|###3      | 2/6 [00:00<00:00,  7.33it/s][I 2021-01-10 18:28:38,773] Trial 38 finished with value: 0.04929970922505001 and parameters: {'feature_fraction': 0.6799999999999999}. Best is trial 37 with value: 0.04872406938298596.
#
# feature_fraction_stage2, val_score: 0.048724:  33%|###3      | 2/6 [00:00<00:00,  7.33it/s]
# feature_fraction_stage2, val_score: 0.048724:  33%|###3      | 2/6 [00:00<00:00,  7.33it/s]
# feature_fraction_stage2, val_score: 0.048724:  50%|#####     | 3/6 [00:00<00:00,  7.81it/s][I 2021-01-10 18:28:38,881] Trial 39 finished with value: 0.04938953154068988 and parameters: {'feature_fraction': 0.584}. Best is trial 37 with value: 0.04872406938298596.
#
# feature_fraction_stage2, val_score: 0.048724:  50%|#####     | 3/6 [00:00<00:00,  7.81it/s]
# feature_fraction_stage2, val_score: 0.048724:  50%|#####     | 3/6 [00:00<00:00,  7.81it/s]
# feature_fraction_stage2, val_score: 0.048724:  67%|######6   | 4/6 [00:00<00:00,  7.96it/s][I 2021-01-10 18:28:39,002] Trial 40 finished with value: 0.049679266469361466 and parameters: {'feature_fraction': 0.6479999999999999}. Best is trial 37 with value: 0.04872406938298596.
#
# feature_fraction_stage2, val_score: 0.048724:  67%|######6   | 4/6 [00:00<00:00,  7.96it/s]
# feature_fraction_stage2, val_score: 0.048724:  67%|######6   | 4/6 [00:00<00:00,  7.96it/s]
# feature_fraction_stage2, val_score: 0.048724:  83%|########3 | 5/6 [00:00<00:00,  7.74it/s][I 2021-01-10 18:28:39,139] Trial 41 finished with value: 0.04872406938298596 and parameters: {'feature_fraction': 0.52}. Best is trial 37 with value: 0.04872406938298596.
#
# feature_fraction_stage2, val_score: 0.048724:  83%|########3 | 5/6 [00:00<00:00,  7.74it/s]
# feature_fraction_stage2, val_score: 0.048724:  83%|########3 | 5/6 [00:00<00:00,  7.74it/s]
# feature_fraction_stage2, val_score: 0.048724: 100%|##########| 6/6 [00:00<00:00,  7.47it/s][I 2021-01-10 18:28:39,284] Trial 42 finished with value: 0.049679266469361466 and parameters: {'feature_fraction': 0.616}. Best is trial 37 with value: 0.04872406938298596.
# feature_fraction_stage2, val_score: 0.048724: 100%|##########| 6/6 [00:00<00:00,  7.51it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
# regularization_factors, val_score: 0.048724:   0%|          | 0/20 [00:00<?, ?it/s]
# regularization_factors, val_score: 0.048724:   0%|          | 0/20 [00:00<?, ?it/s]
# regularization_factors, val_score: 0.048724:   5%|5         | 1/20 [00:00<00:02,  8.35it/s][I 2021-01-10 18:28:39,412] Trial 43 finished with value: 0.049579594675434734 and parameters: {'lambda_l1': 2.415902853176718, 'lambda_l2': 4.617891317159114e-06}. Best is trial 43 with value: 0.049579594675434734.
#
# regularization_factors, val_score: 0.048724:   5%|5         | 1/20 [00:00<00:02,  8.35it/s]
# regularization_factors, val_score: 0.048724:   5%|5         | 1/20 [00:00<00:02,  8.35it/s]
# regularization_factors, val_score: 0.048724:  10%|#         | 2/20 [00:00<00:02,  8.59it/s][I 2021-01-10 18:28:39,521] Trial 44 finished with value: 0.04999818432311137 and parameters: {'lambda_l1': 1.2299662611277836e-08, 'lambda_l2': 3.3136255324913626}. Best is trial 43 with value: 0.049579594675434734.
#
# regularization_factors, val_score: 0.048724:  10%|#         | 2/20 [00:00<00:02,  8.59it/s]
# regularization_factors, val_score: 0.048724:  10%|#         | 2/20 [00:00<00:02,  8.59it/s]
# ...
# num_leaves, val_score: 0.051354:  20%|##        | 4/20 [00:03<00:13,  1.23it/s][I 2021-01-10 18:42:32,317] Trial 10 finished with value: 0.05229593535885592 and parameters: {'num_leaves': 246}. Best is trial 7 with value: 0.05135405977089343.
# num_leaves, val_score: 0.048653:  25%|##5       | 5/20 [00:03<00:09,  1.56it/s][I 2021-01-10 18:42:32,558] Trial 11 finished with value: 0.048652946296207214 and parameters: {'num_leaves': 2}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653:  30%|###       | 6/20 [00:03<00:07,  1.89it/s][I 2021-01-10 18:42:32,825] Trial 12 finished with value: 0.05030775161234753 and parameters: {'num_leaves': 5}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653:  35%|###5      | 7/20 [00:04<00:08,  1.53it/s][I 2021-01-10 18:42:33,766] Trial 13 finished with value: 0.05229593535885592 and parameters: {'num_leaves': 119}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653:  40%|####      | 8/20 [00:05<00:07,  1.55it/s][I 2021-01-10 18:42:34,390] Trial 14 finished with value: 0.05017421775744997 and parameters: {'num_leaves': 18}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653:  45%|####5     | 9/20 [00:06<00:07,  1.43it/s][I 2021-01-10 18:42:35,222] Trial 15 finished with value: 0.05229593535885592 and parameters: {'num_leaves': 88}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653:  50%|#####     | 10/20 [00:06<00:07,  1.35it/s][I 2021-01-10 18:42:36,060] Trial 16 finished with value: 0.05229593535885592 and parameters: {'num_leaves': 229}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653:  55%|#####5    | 11/20 [00:07<00:06,  1.37it/s][I 2021-01-10 18:42:36,762] Trial 17 finished with value: 0.05229593535885592 and parameters: {'num_leaves': 173}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653:  60%|######    | 12/20 [00:08<00:05,  1.56it/s][I 2021-01-10 18:42:37,199] Trial 18 finished with value: 0.05229593535885592 and parameters: {'num_leaves': 55}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653:  65%|######5   | 13/20 [00:08<00:03,  1.87it/s][I 2021-01-10 18:42:37,488] Trial 19 finished with value: 0.05030775161234753 and parameters: {'num_leaves': 5}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653:  70%|#######   | 14/20 [00:08<00:03,  1.89it/s][I 2021-01-10 18:42:38,005] Trial 20 finished with value: 0.05229593535885592 and parameters: {'num_leaves': 168}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653:  75%|#######5  | 15/20 [00:09<00:02,  2.12it/s][I 2021-01-10 18:42:38,337] Trial 21 finished with value: 0.05021603605116172 and parameters: {'num_leaves': 9}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653:  80%|########  | 16/20 [00:09<00:01,  2.06it/s][I 2021-01-10 18:42:38,854] Trial 22 finished with value: 0.05229593535885592 and parameters: {'num_leaves': 40}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653:  85%|########5 | 17/20 [00:09<00:01,  2.51it/s][I 2021-01-10 18:42:39,053] Trial 23 finished with value: 0.051375369329340975 and parameters: {'num_leaves': 4}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653:  90%|######### | 18/20 [00:10<00:00,  2.23it/s][I 2021-01-10 18:42:39,619] Trial 24 finished with value: 0.05229593535885592 and parameters: {'num_leaves': 93}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653:  95%|#########5| 19/20 [00:10<00:00,  2.59it/s][I 2021-01-10 18:42:39,859] Trial 25 finished with value: 0.048652946296207214 and parameters: {'num_leaves': 2}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653: 100%|##########| 20/20 [00:11<00:00,  2.25it/s][I 2021-01-10 18:42:40,439] Trial 26 finished with value: 0.05229593535885592 and parameters: {'num_leaves': 53}. Best is trial 11 with value: 0.048652946296207214.
# num_leaves, val_score: 0.048653: 100%|##########| 20/20 [00:11<00:00,  1.77it/s]
# bagging, val_score: 0.048653:  10%|#         | 1/10 [00:00<00:01,  6.43it/s][I 2021-01-10 18:42:40,600] Trial 27 finished with value: 0.04938708901814838 and parameters: {'bagging_fraction': 0.5452940059826111, 'bagging_freq': 6}. Best is trial 27 with value: 0.04938708901814838.
# bagging, val_score: 0.048653:  20%|##        | 2/10 [00:00<00:01,  6.53it/s][I 2021-01-10 18:42:40,748] Trial 28 finished with value: 0.04921720706414339 and parameters: {'bagging_fraction': 0.5460022784085088, 'bagging_freq': 6}. Best is trial 28 with value: 0.04921720706414339.
# bagging, val_score: 0.048653:  30%|###       | 3/10 [00:00<00:01,  6.30it/s][I 2021-01-10 18:42:40,919] Trial 29 finished with value: 0.04921160459419143 and parameters: {'bagging_fraction': 0.8273248656920296, 'bagging_freq': 4}. Best is trial 29 with value: 0.04921160459419143.
# bagging, val_score: 0.048653:  40%|####      | 4/10 [00:00<00:01,  5.81it/s][I 2021-01-10 18:42:41,124] Trial 30 finished with value: 0.0502226302170742 and parameters: {'bagging_fraction': 0.9963253876257766, 'bagging_freq': 1}. Best is trial 29 with value: 0.04921160459419143.
# bagging, val_score: 0.048653:  50%|#####     | 5/10 [00:00<00:00,  5.80it/s][I 2021-01-10 18:42:41,296] Trial 31 finished with value: 0.049074933674161554 and parameters: {'bagging_fraction': 0.8268417143969307, 'bagging_freq': 4}. Best is trial 31 with value: 0.049074933674161554.
# bagging, val_score: 0.048653:  60%|######    | 6/10 [00:01<00:00,  5.94it/s][I 2021-01-10 18:42:41,454] Trial 32 finished with value: 0.05029424061929495 and parameters: {'bagging_fraction': 0.8715549386357386, 'bagging_freq': 3}. Best is trial 31 with value: 0.049074933674161554.
# bagging, val_score: 0.048653:  70%|#######   | 7/10 [00:01<00:00,  5.82it/s][I 2021-01-10 18:42:41,634] Trial 33 finished with value: 0.04929010087693334 and parameters: {'bagging_fraction': 0.799154228799197, 'bagging_freq': 4}. Best is trial 31 with value: 0.049074933674161554.
# bagging, val_score: 0.048653:  80%|########  | 8/10 [00:01<00:00,  5.62it/s][I 2021-01-10 18:42:41,826] Trial 34 finished with value: 0.04915989859424599 and parameters: {'bagging_fraction': 0.7496653065070279, 'bagging_freq': 4}. Best is trial 31 with value: 0.049074933674161554.
# bagging, val_score: 0.048653:  90%|######### | 9/10 [00:01<00:00,  5.85it/s][I 2021-01-10 18:42:41,982] Trial 35 finished with value: 0.04959583533675558 and parameters: {'bagging_fraction': 0.683004633650984, 'bagging_freq': 3}. Best is trial 31 with value: 0.049074933674161554.
# bagging, val_score: 0.048653: 100%|##########| 10/10 [00:01<00:00,  6.05it/s][I 2021-01-10 18:42:42,133] Trial 36 finished with value: 0.049979693238476425 and parameters: {'bagging_fraction': 0.6874439826433856, 'bagging_freq': 5}. Best is trial 31 with value: 0.049074933674161554.
# bagging, val_score: 0.048653: 100%|##########| 10/10 [00:01<00:00,  5.91it/s]
# feature_fraction_stage2, val_score: 0.048653:  33%|###3      | 1/3 [00:00<00:00,  3.77it/s][I 2021-01-10 18:42:42,403] Trial 37 finished with value: 0.049274300920390264 and parameters: {'feature_fraction': 0.92}. Best is trial 37 with value: 0.049274300920390264.
# feature_fraction_stage2, val_score: 0.048653:  67%|######6   | 2/3 [00:00<00:00,  4.23it/s][I 2021-01-10 18:42:42,572] Trial 38 finished with value: 0.04929875696766731 and parameters: {'feature_fraction': 0.9520000000000001}. Best is trial 37 with value: 0.049274300920390264.
# feature_fraction_stage2, val_score: 0.048653: 100%|##########| 3/3 [00:00<00:00,  4.22it/s][I 2021-01-10 18:42:42,810] Trial 39 finished with value: 0.048652946296207214 and parameters: {'feature_fraction': 0.9840000000000001}. Best is trial 39 with value: 0.048652946296207214.
# feature_fraction_stage2, val_score: 0.048653: 100%|##########| 3/3 [00:00<00:00,  4.45it/s]
# regularization_factors, val_score: 0.048653:   5%|5         | 1/20 [00:00<00:04,  4.17it/s][I 2021-01-10 18:42:43,055] Trial 40 finished with value: 0.0510383520413509 and parameters: {'lambda_l1': 4.596937131131766, 'lambda_l2': 6.619088976498625}. Best is trial 40 with value: 0.0510383520413509.
# regularization_factors, val_score: 0.048653:  10%|#         | 2/20 [00:00<00:04,  4.06it/s][I 2021-01-10 18:42:43,317] Trial 41 finished with value: 0.04865398711865866 and parameters: {'lambda_l1': 2.2202611016065838e-08, 'lambda_l2': 2.3648551820870827e-08}. Best is trial 41 with value: 0.04865398711865866.
# regularization_factors, val_score: 0.048653:  15%|#5        | 3/20 [00:00<00:04,  4.08it/s][I 2021-01-10 18:42:43,559] Trial 42 finished with value: 0.04865398715164745 and parameters: {'lambda_l1': 1.3718619357465514e-08, 'lambda_l2': 1.4724749226860706e-08}. Best is trial 41 with value: 0.04865398711865866.
# regularization_factors, val_score: 0.048653:  20%|##        | 4/20 [00:00<00:03,  4.11it/s][I 2021-01-10 18:42:43,798] Trial 43 finished with value: 0.04865398715413286 and parameters: {'lambda_l1': 1.288955397997043e-08, 'lambda_l2': 1.039783223924093e-08}. Best is trial 41 with value: 0.04865398711865866.
# regularization_factors, val_score: 0.048653:  25%|##5       | 5/20 [00:01<00:03,  4.12it/s][I 2021-01-10 18:42:44,041] Trial 44 finished with value: 0.04865398713793427 and parameters: {'lambda_l1': 1.0398177711182648e-08, 'lambda_l2': 1.8506070931673998e-08}. Best is trial 41 with value: 0.04865398711865866.
# regularization_factors, val_score: 0.048653:  30%|###       | 6/20 [00:01<00:03,  4.12it/s][I 2021-01-10 18:42:44,282] Trial 45 finished with value: 0.04865398288807359 and parameters: {'lambda_l1': 5.212124754316026e-06, 'lambda_l2': 4.4724305744094234e-06}. Best is trial 45 with value: 0.04865398288807359.
# regularization_factors, val_score: 0.048653:  35%|###5      | 7/20 [00:01<00:03,  4.11it/s][I 2021-01-10 18:42:44,527] Trial 46 finished with value: 0.048653952394599666 and parameters: {'lambda_l1': 3.733097493525637e-05, 'lambda_l2': 3.792048290883409e-05}. Best is trial 46 with value: 0.048653952394599666.
# regularization_factors, val_score: 0.048653:  40%|####      | 8/20 [00:01<00:02,  4.13it/s][I 2021-01-10 18:42:44,766] Trial 47 finished with value: 0.048653904402323644 and parameters: {'lambda_l1': 8.138582470976159e-05, 'lambda_l2': 9.214405660193465e-05}. Best is trial 47 with value: 0.048653904402323644.
# regularization_factors, val_score: 0.048652:  45%|####5     | 9/20 [00:02<00:02,  4.03it/s][I 2021-01-10 18:42:45,028] Trial 48 finished with value: 0.04865173360080631 and parameters: {'lambda_l1': 0.000979663424358248, 'lambda_l2': 0.0029403063243032806}. Best is trial 48 with value: 0.04865173360080631.
# regularization_factors, val_score: 0.048487:  50%|#####     | 10/20 [00:02<00:02,  4.46it/s][I 2021-01-10 18:42:45,197] Trial 49 finished with value: 0.0484866797740201 and parameters: {'lambda_l1': 0.0150357331278082, 'lambda_l2': 0.12583037008135523}. Best is trial 49 with value: 0.0484866797740201.
# regularization_factors, val_score: 0.048487:  55%|#####5    | 11/20 [00:02<00:01,  4.77it/s][I 2021-01-10 18:42:45,373] Trial 50 finished with value: 0.04870197605882927 and parameters: {'lambda_l1': 0.12219664446487737, 'lambda_l2': 0.22754360608289054}. Best is trial 49 with value: 0.0484866797740201.
# regularization_factors, val_score: 0.048487:  60%|######    | 12/20 [00:02<00:01,  5.11it/s][I 2021-01-10 18:42:45,536] Trial 51 finished with value: 0.048825669628924206 and parameters: {'lambda_l1': 0.004699133429392591, 'lambda_l2': 0.007893678611459568}. Best is trial 49 with value: 0.0484866797740201.
# regularization_factors, val_score: 0.048487:  65%|######5   | 13/20 [00:02<00:01,  4.79it/s][I 2021-01-10 18:42:45,775] Trial 52 finished with value: 0.04865194294719332 and parameters: {'lambda_l1': 0.0019120876192700554, 'lambda_l2': 0.0023727136558807558}. Best is trial 49 with value: 0.0484866797740201.
# regularization_factors, val_score: 0.048487:  70%|#######   | 14/20 [00:03<00:01,  5.13it/s][I 2021-01-10 18:42:45,938] Trial 53 finished with value: 0.04882428238140926 and parameters: {'lambda_l1': 0.0063201809974242585, 'lambda_l2': 0.00976955016261756}. Best is trial 49 with value: 0.0484866797740201.
# regularization_factors, val_score: 0.048487:  75%|#######5  | 15/20 [00:03<00:00,  5.37it/s][I 2021-01-10 18:42:46,103] Trial 54 finished with value: 0.04882500383964283 and parameters: {'lambda_l1': 0.0039384632885581024, 'lambda_l2': 0.008884732407321074}. Best is trial 49 with value: 0.0484866797740201.
# regularization_factors, val_score: 0.048487:  80%|########  | 16/20 [00:03<00:00,  5.14it/s][I 2021-01-10 18:42:46,318] Trial 55 finished with value: 0.04932235984142581 and parameters: {'lambda_l1': 0.20489533189173878, 'lambda_l2': 0.48667290393618434}. Best is trial 49 with value: 0.0484866797740201.
# regularization_factors, val_score: 0.048487:  85%|########5 | 17/20 [00:03<00:00,  4.67it/s][I 2021-01-10 18:42:46,577] Trial 56 finished with value: 0.0486531973419457 and parameters: {'lambda_l1': 0.0007902051428937563, 'lambda_l2': 0.0008849264419963004}. Best is trial 49 with value: 0.0484866797740201.
# regularization_factors, val_score: 0.048487:  90%|######### | 18/20 [00:03<00:00,  4.95it/s][I 2021-01-10 18:42:46,751] Trial 57 finished with value: 0.048546588320693834 and parameters: {'lambda_l1': 0.0992631643840983, 'lambda_l2': 0.09290594886176737}. Best is trial 49 with value: 0.0484866797740201.
# regularization_factors, val_score: 0.048487:  95%|#########5| 19/20 [00:04<00:00,  4.72it/s][I 2021-01-10 18:42:46,985] Trial 58 finished with value: 0.04892433908165502 and parameters: {'lambda_l1': 0.21912664059309492, 'lambda_l2': 0.3670522344924444}. Best is trial 49 with value: 0.0484866797740201.
# regularization_factors, val_score: 0.048487: 100%|##########| 20/20 [00:04<00:00,  5.01it/s][I 2021-01-10 18:42:47,157] Trial 59 finished with value: 0.04875897905087612 and parameters: {'lambda_l1': 0.04106155366292771, 'lambda_l2': 0.05808423578618492}. Best is trial 49 with value: 0.0484866797740201.
# regularization_factors, val_score: 0.048487: 100%|##########| 20/20 [00:04<00:00,  4.60it/s]
# min_data_in_leaf, val_score: 0.048487:  20%|##        | 1/5 [00:00<00:00,  5.32it/s][I 2021-01-10 18:42:47,350] Trial 60 finished with value: 0.0484866797740201 and parameters: {'min_child_samples': 100}. Best is trial 60 with value: 0.0484866797740201.
# min_data_in_leaf, val_score: 0.048487:  40%|####      | 2/5 [00:00<00:00,  5.40it/s][I 2021-01-10 18:42:47,529] Trial 61 finished with value: 0.0484866797740201 and parameters: {'min_child_samples': 5}. Best is trial 60 with value: 0.0484866797740201.
# min_data_in_leaf, val_score: 0.048487:  60%|######    | 3/5 [00:00<00:00,  5.43it/s][I 2021-01-10 18:42:47,711] Trial 62 finished with value: 0.0484866797740201 and parameters: {'min_child_samples': 50}. Best is trial 60 with value: 0.0484866797740201.
# min_data_in_leaf, val_score: 0.048487:  80%|########  | 4/5 [00:00<00:00,  5.47it/s][I 2021-01-10 18:42:47,890] Trial 63 finished with value: 0.0484866797740201 and parameters: {'min_child_samples': 25}. Best is trial 60 with value: 0.0484866797740201.
# min_data_in_leaf, val_score: 0.048487: 100%|##########| 5/5 [00:00<00:00,  5.29it/s][I 2021-01-10 18:42:48,094] Trial 64 finished with value: 0.0484866797740201 and parameters: {'min_child_samples': 10}. Best is trial 60 with value: 0.0484866797740201.
# min_data_in_leaf, val_score: 0.048487: 100%|##########| 5/5 [00:00<00:00,  5.35it/s]
# [I 2021-01-10 18:42:48,103] Trial 49 finished with value: 0.55 and parameters: {'lambda_l1': 1.1705015109543327e-05, 'lambda_l2': 0.0014519965622787655, 'num_leaves': 277, 'feature_fraction': 0.44284831953398873, 'bagging_fraction': 0.570495414902557, 'bagging_freq': 1, 'min_child_samples': 8}. Best is trial 15 with value: 0.6.

# %%
#ベストパラメータ
print('Number of finished trials:', len(study.trials))
#Number of finished trials: 50
# Out:
# Number of finished trials: 50

# %%
print('Best trial:', display(study.best_trial.params))

#初回
# {'lambda_l1': 5.204866804465978e-08,
#  'lambda_l2': 3.133667635701077e-05,
#  'num_leaves': 317,
#  'feature_fraction': 0.848640913268004,
#  'bagging_fraction': 0.4983467582046316,
#  'bagging_freq': 4,
#  'min_child_samples': 22}
# Best trial: None

#2回目
# {'lambda_l1': 0.00416566836241902,
#  'lambda_l2': 0.10371698288325823,
#  'num_leaves': 333,
#  'feature_fraction': 0.6873251818776734,
#  'bagging_fraction': 0.6363448284692337,
#  'bagging_freq': 10,
#  'min_child_samples': 17}
# Best trial: None
# Out:
# {'lambda_l1': 0.003158141941182639,
#  'lambda_l2': 0.0008853206993091085,
#  'num_leaves': 380,
#  'feature_fraction': 0.5686541926682908,
#  'bagging_fraction': 0.6569913398412971,
#  'bagging_freq': 0,
#  'min_child_samples': 5}
# Best trial: None

# %%
# def create_feature_together(train, test, num_cols):
#     train, test = transform_box_cox(train, test, num_cols)
#     return train, test

# # issue 14 Box-Cox変換
# def transform_box_cox(train, test, column):
#     pt = PowerTransformer(method='box-cox')
#     pt.fit(train[column])

#     # 変換後のデータで各列を置換
#     train[column] = pt.transform(train[column])
#     test[column] = pt.transform(test[column])

#特徴量作成（train_dataとtest_dataで同一の処理が必要）
#変換するカラム
# num_cols = ['all_purchase_price']
# train_data, test_data = create_feature_together(train_data, test_data, num_cols)

# %%
# tr_x, va_x, tr_y, va_y = train_test_split(train_x, train_y,
#                                           test_size=0.25, random_state=71, shuffle=True)
# kf = KFold(n_splits=4, shuffle=True, random_state=71)
# for tr_idx, va_idx in kf.split(train_x):
#     tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
#     tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]
