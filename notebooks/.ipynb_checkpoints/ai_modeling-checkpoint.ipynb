# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import datetime
import jpholiday
import statsmodels.api as sm
from statsmodels.graphics import tsaplots
# from optuna.integration import lightgbm as lgb
import lightgbm as lgb
from sklearn.metrics import  log_loss
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from datetime import date, timedelta
import sklearn.metrics
import optuna 
from dateutil.relativedelta import relativedelta
import pandas_profiling as pdp


# %matplotlib inline

# %% [markdown]
# # 基準モデルの作成

# %%
FILE_PATH = '/Users/atsushisato/git_clone/ai_quest_season2/data/'

train_data = pd.read_csv(FILE_PATH + 'external/train.csv').rename(columns={'顧客ID':'uuid', 'クーポンID':'coupon_id', 'クーポン利用':'coupon_use_result'})
test_data = pd.read_csv(FILE_PATH + 'external/test.csv').rename(columns={'顧客ID':'uuid', 'クーポンID':'coupon_id'})
customer_df = pd.read_csv(FILE_PATH + 'interim/customer_df.csv')

# %% [markdown]
# # 特徴量作成

# %%
#特徴量作成関数（trainとtestで異なる処理が可能）
def create_feature_separate(dataframe):
    # issue 9/10 カテゴリ変数の数値変換 
    dataframe = category_to_int_conversion(dataframe)
    
    # issue 11 カテゴリ別商品単価
    dataframe['unit_price_category'] = dataframe.apply(lambda x: 
                                unit_price_category(x['purchase_product_num'], x['coupon_use'], x['purchase_price']),axis=1)
    # issue 16 総購入商品の平均
    dataframe['purchase_price_average'] = dataframe.apply(lambda x: 
                                purchase_price_average(x['all_purchase_price'], x['visits_frequency']),axis=1)   
    # issue 20 平均来店周期
    dataframe['visit_cycle'] = dataframe.apply(lambda x:
                                visit_cycle(x['visits_frequency'], x['pass_days']),axis=1)
    # issue 21 経過日数と来店頻度の比較
    dataframe['visit_cycle_flg'] = dataframe.apply(lambda x: 
                                visit_cycle_flg(x['visit_cycle'], x['pass_days']),axis=1) 
    # issue 22 総購入金額に占めるカテゴリ別の購入金額比率
    dataframe['ratio_category'] = dataframe.apply(lambda x:
                                ratio_category(x['all_purchase_price'], x['purchase_price']),axis=1)
    # issue 23 大人の数
    dataframe['adult_num'] = dataframe['fammily_num'] - dataframe['child_num']
    
    # issue 24 カテゴリ別平均購入金額
    dataframe['purchase_price_category_average'] = dataframe.apply(lambda x:
                                purchase_price_category_average(x['purchase_price'], x['purchase_product_num'],x['coupon_use']),axis=1)
    # issue 28 家族1人あたりの総購入金額
    dataframe['purchase_price_1person'] = dataframe.apply(lambda x:
                                purchase_price_1person(x['all_purchase_price'], x['fammily_num']),axis=1)
    # issue 29 1日あたりの購入金額
    dataframe['purchase_price_1day'] = dataframe.apply(lambda x :
                                purchase_price_1day(x['all_purchase_price'], x['pass_days']),axis=1)
    
    
    dataframe = dataframe.drop(['age_range', 'marry',],axis=1)
    dataframe = dataframe.drop(['category_id', 'house_flg', 'marry_flg', 'age', 'visit_cycle_flg', 'category_id'],axis=1)
    return dataframe

# %%
#===================================================================================
#特徴量作成関数
# issue 9/10 カテゴリ変数の数値変換    
def category_to_int_conversion(dataframe):
    marry_dict = {'無回答':None, '独身':0, '既婚':1}
    dataframe['marry_flg'] = dataframe['marry'].apply(lambda x: marry_dict.get(x))
    
    dataframe['age'] = dataframe['age_range'].apply(lambda x: int(x[:2]))
    dataframe['category_id'] = dataframe['category_id'].apply(lambda x: int(x[1:]))
    
    dataframe = dataframe.drop(['category'],axis=1)
    return dataframe

# issue 11 カテゴリ別商品単価
def unit_price_category(product_num, coupon_use, price):
    if coupon_use != 0:
        price = price + abs(coupon_use)
    
    if price != 0:
        return int(price / product_num)
    else:
        return 0
    
# issue 16 総購入商品の平均
def purchase_price_average(all_purchase_price, visits_frequency):
    if (all_purchase_price != 0) & (visits_frequency != 0):
        one_purchase_price =  int(all_purchase_price / visits_frequency)            
    else:
        one_purchase_price =  0
    return one_purchase_price

# issue 20 平均来店周期
def visit_cycle(visits_frequency, pass_days):
    all_days = 60
    if visits_frequency != 0:
        cycle = int((all_days - pass_days) / visits_frequency)
    else:
        cycle = 0
    return cycle

# issue 21 経過日数と来店頻度の比較
def visit_cycle_flg(visit_cycle, pass_days):
    if visit_cycle <= pass_days:
        return 1
    else:
        return 0
    
# issue 22 総購入金額に占めるカテゴリ別の購入金額比率
def ratio_category(all_purchase_price, purchase_price):
    if purchase_price != 0:
        ratio = purchase_price / all_purchase_price
    else:
        ratio = 0
    return ratio

# issue 24 カテゴリ別平均購入金額
def purchase_price_category_average(purchase_price, purchase_product_num, coupon_use):
    if purchase_product_num != 0:
        purchase_price = purchase_price + abs(coupon_use)
        average_purchase = int(purchase_price / purchase_product_num)
    else:
        average_purchase = 0
    return average_purchase
    
# issue 28 家族1人あたりの総購入金額
def purchase_price_1person(all_purchase_price, fammily_num):
    if all_purchase_price != 0:
        return int(all_purchase_price / fammily_num)
    else:
        return 0

# issue 29 1日あたりの購入金額
def purchase_price_1day(all_purchase_price, pass_days):
    if all_purchase_price != 0:
        all_days = 60
        use_days = all_days - pass_days + 1
        return int(all_purchase_price / use_days)
    else:
        return 0
    
# issue 19 欠損値削除（購入履歴はあるが来店履歴がないuuid）
def drop_missing_value(dataframe):
    drop_uuid = dataframe.query("(visits_frequency ==0 )& (all_purchase_price != 0)")['uuid'].unique()
    dataframe = dataframe.query("uuid not in @drop_uuid") 
    return dataframe

# %%
#train_dataとtest_dataの特徴量作成
train_data = pd.merge(train_data, customer_df, on=['uuid', 'coupon_id'],how='inner')
test_data = pd.merge(test_data, customer_df, on=['uuid', 'coupon_id'],how='inner')

#特徴量作成（train_dataとtest_dataで異なる処理が可能）
train_data = create_feature_separate(train_data)
test_data = create_feature_separate(test_data)
train_data = drop_missing_value(train_data)

# %%
# pdp.ProfileReport(train_data.query("coupon_use_result == 1"))

# %%
sorted(train_data.columns)
# Out:
# ['adult_num',
#  'all_purchase_price',
#  'child_num',
#  'coupon_id',
#  'coupon_use',
#  'coupon_use_result',
#  'fammily_num',
#  'income',
#  'pass_days',
#  'purchase_num',
#  'purchase_price',
#  'purchase_price_1day',
#  'purchase_price_1person',
#  'purchase_price_average',
#  'purchase_price_category_average',
#  'purchase_product_num',
#  'ratio_category',
#  'unit_price_category',
#  'uuid',
#  'visit_cycle',
#  'visits_frequency']

# %%
train_data.query("coupon_use_result == 0").describe()
# Out:
#               uuid    coupon_id  coupon_use_result  fammily_num    child_num  \
# count  3823.000000  3823.000000             3823.0  3823.000000  3823.000000
# mean    178.917866     5.985875                0.0     2.076380     0.470834
# std     102.638588     3.163073                0.0     1.143967     0.904738
# min       1.000000     1.000000                0.0     1.000000     0.000000
# 25%      90.000000     3.000000                0.0     1.000000     0.000000
# 50%     179.000000     6.000000                0.0     2.000000     0.000000
# 75%     268.000000     9.000000                0.0     2.000000     1.000000
# max     356.000000    11.000000                0.0     5.000000     3.000000
#
#             income  visits_frequency    pass_days  all_purchase_price  \
# count  3823.000000       3823.000000  3823.000000         3823.000000
# mean      4.467434         14.054931    18.241172        76559.030866
# std       2.259447          9.744089    17.656778        58808.592828
# min       1.000000          0.000000     0.000000            0.000000
# 25%       3.000000          7.000000     4.000000        36786.000000
# 50%       4.000000         11.000000    10.000000        62914.000000
# 75%       6.000000         19.000000    34.000000       106227.000000
# max      12.000000         60.000000    58.000000       381738.000000
#
#        purchase_num  ...   coupon_use  purchase_price  unit_price_category  \
# count   3823.000000  ...  3823.000000     3823.000000          3823.000000
# mean       4.330630  ...   -28.865551     6660.060685           422.139942
# std        6.405863  ...   224.247908    17891.492788           454.348973
# min        0.000000  ... -5182.000000        0.000000             0.000000
# 25%        0.000000  ...     0.000000        0.000000             0.000000
# 50%        2.000000  ...     0.000000     1280.000000           369.000000
# 75%        6.000000  ...     0.000000     4302.500000           597.000000
# max       60.000000  ...     0.000000   283051.000000          7122.000000
#
#        purchase_price_average  visit_cycle  ratio_category    adult_num  \
# count             3823.000000  3823.000000     3823.000000  3823.000000
# mean              6229.314151     3.271776        0.087936     1.605545
# std               4921.461521     2.169229        0.179046     0.488797
# min                  0.000000     0.000000        0.000000     1.000000
# 25%               3247.000000     2.000000        0.000000     1.000000
# 50%               4925.000000     3.000000        0.018270     2.000000
# 75%               7559.000000     4.000000        0.064670     2.000000
# max              42507.000000    22.000000        1.000000     2.000000
#
#        purchase_price_category_average  purchase_price_1person  \
# count                      3823.000000             3823.000000
# mean                        422.139942            44953.535705
# std                         454.348973            40517.789921
# min                           0.000000                0.000000
# 25%                           0.000000            19259.000000
# 50%                         369.000000            34325.000000
# 75%                         597.000000            55547.000000
# max                        7122.000000           257970.000000
#
#        purchase_price_1day
# count          3823.000000
# mean           1881.293225
# std            1344.037422
# min               0.000000
# 25%             937.000000
# 50%            1605.000000
# 75%            2406.000000
# max            8327.000000
#
# [8 rows x 21 columns]

# %%
train_data.query("coupon_use_result == 1")
# Out:
#       uuid  coupon_id  coupon_use_result  fammily_num  child_num  income  \
# 62       6          8                  1            4          2       7
# 110     11          1                  1            4          2       1
# 139     13          8                  1            2          0       4
# 266     25          3                  1            5          3      12
# 273     25         10                  1            5          3      12
# 286     27          1                  1            5          3       6
# 304     28          8                  1            2          0       5
# 315     29          8                  1            4          2       5
# 316     29          9                  1            4          2       5
# 339     31         10                  1            2          0       5
# 348     32          8                  1            1          0       5
# 657     60          9                  1            2          0      10
# 729     67          4                  1            4          2       5
# 760     70          2                  1            2          0       1
# 829     76          5                  1            1          0       4
# 844     77          9                  1            2          0       5
# 866     79          9                  1            2          1       4
# 964     88          8                  1            4          2       5
# 989     90         11                  1            4          2       4
# 1096   100          8                  1            1          0       1
# 1118   102          8                  1            4          2       5
# 1173   107          8                  1            2          0       5
# 1399   128          3                  1            2          0       5
# 1404   128          8                  1            2          0       5
# 1437   131          8                  1            2          0       4
# 1493   136          9                  1            2          0       6
# 1632   149          5                  1            2          0       3
# 1646   150          8                  1            1          0       5
# 1657   151          8                  1            3          1       1
# 1789   163          8                  1            1          0       9
# 1860   170          2                  1            2          0      12
# 1864   170          6                  1            2          0      12
# 2155   196         11                  1            2          0       6
# 2174   198          8                  1            2          0       8
# 2297   209         10                  1            2          0       9
# 2607   238          1                  1            3          1       1
# 2681   244          9                  1            4          2       7
# 2724   248          8                  1            4          2       1
# 2817   257          2                  1            1          0       5
# 3086   281          7                  1            4          2       9
# 3094   282          4                  1            5          3       8
# 3186   290          8                  1            2          0       4
# 3222   293         11                  1            1          0       6
# 3263   297          8                  1            2          0       4
# 3367   307          2                  1            2          0       1
# 3376   307         11                  1            2          0       1
# 3574   325         11                  1            1          0       3
# 3605   328          9                  1            2          0      12
# 3901   355          8                  1            1          0       5
#
#       visits_frequency  pass_days  all_purchase_price  purchase_num  ...  \
# 62                  27          6              167426            27  ...
# 110                 14          9               99178             1  ...
# 139                 10          5               40436            10  ...
# 266                 20          4              193721             2  ...
# 273                 20          4              193721             1  ...
# 286                  6         15               70823             2  ...
# 304                  6         18              165004             6  ...
# 315                 26          3               97148            26  ...
# 316                 26          3               97148            18  ...
# 339                 20          3               96416             0  ...
# 348                 25          5              148412            25  ...
# 657                 16          9              132110            16  ...
# 729                 13          2              181821             7  ...
# 760                 36          1              138159             3  ...
# 829                 28          3               44513             6  ...
# 844                  8         27               48423             8  ...
# 866                 14         13              175538            14  ...
# 964                 18          8              129520            18  ...
# 989                  8         38               54568             0  ...
# 1096                30          1              147774            30  ...
# 1118                22         14              160788            22  ...
# 1173                21          6               60767            21  ...
# 1399                18          1              170483             1  ...
# 1404                18          1              170483            18  ...
# 1437                 9         16               81125             9  ...
# 1493                23          3              181234            23  ...
# 1632                 9          3               65767             9  ...
# 1646                36          1              134526            36  ...
# 1657                17          9               52701            17  ...
# 1789                26          4              123798            26  ...
# 1860                36          1              210339             4  ...
# 1864                36          1              210339            14  ...
# 2155                17          8               97150             1  ...
# 2174                43          1              206252            43  ...
# 2297                17          9              114127             2  ...
# 2607                23         12               93378             3  ...
# 2681                10          3              212453            10  ...
# 2724                26          2              116906            26  ...
# 2817                 3         51               21458             1  ...
# 3086                30          1              121413             7  ...
# 3094                38          1              273384             7  ...
# 3186                11          5              126321            11  ...
# 3222                29          2              199159             0  ...
# 3263                13          8               21764            13  ...
# 2155            3        0.007308          2                              710
# 2174            1        0.670078          2                              364
# 2297            3        0.021809          2                             1244
# 2607            2        0.008096          2                              189
# 2681            5        0.203245          2                              591
# 2724            2        0.592296          2                              392
# 2817            3        0.067294          1                             1444
# 3086            1        0.027015          2                              468
# 3094            1        0.010388          2                              258
# 3186            5        0.616232          2                              509
# 3222            2        0.000000          1                                0
# 3263            4        0.615098          2                              245
# 3367            2        0.058688          2                              714
# 3376            2        0.000000          2                                0
# 3574            4        0.013737          1                              712
# 3605            1        0.127826          2                              509
# 3901            2        0.686675          1                              403
#
#       purchase_price_1person  purchase_price_1day
# 62                     41856                 3044
# 110                    24794                 1907
# 139                    20218                  722
# 266                    38744                 3398
# 273                    38744                 3398
# 286                    14164                 1539
# 304                    82502                 3837
# 315                    24287                 1674
# 316                    24287                 1674
# 339                    48208                 1662
# 348                   148412                 2650
# 657                    66055                 2540
# 729                    45455                 3081
# 760                    69079                 2302
# 829                    44513                  767
# 844                    24211                 1424
# 866                    87769                 3657
# 964                    32380                 2443
# 989                    13642                 2372
# 1096                  147774                 2462
# 1118                   40197                 3421
# 1173                   30383                 1104
# 1399                   85241                 2841
# 1404                   85241                 2841
# 1437                   40562                 1802
# 1493                   90617                 3124
# 1632                   32883                 1133
# 1646                  134526                 2242
# 1657                   17567                 1013
# 1789                  123798                 2171
# 1860                  105169                 3505
# 1864                  105169                 3505
# 2155                   48575                 1833
# 2174                  103126                 3437
# 2297                   57063                 2194
# 2607                   31126                 1905
# 2681                   53113                 3662
# 2724                   29226                 1981
# 2817                   21458                 2145
# 3086                   30353                 2023
# 3094                   54676                 4556
# 3186                   63160                 2255
# 3222                  199159                 3375
# 3263                   10882                  410
# 3367                   30449                 1127
# 3376                   30449                 1127
# 3574                   51831                  959
# 3605                  150001                 5000
# 3901                  191702                 3423
#
# [49 rows x 21 columns]

# %%
train_data.head(11)
# Out:
#     uuid  coupon_id  coupon_use_result  fammily_num  child_num  income  \
# 0      1          1                  0            1          0       5
# 1      1          2                  0            1          0       5
# 2      1          3                  0            1          0       5
# 3      1          4                  0            1          0       5
# 4      1          5                  0            1          0       5
# 5      1          6                  0            1          0       5
# 6      1          7                  0            1          0       5
# 7      1          8                  0            1          0       5
# 8      1          9                  0            1          0       5
# 9      1         10                  0            1          0       5
# 10     1         11                  0            1          0       5
#
#     visits_frequency  pass_days  all_purchase_price  purchase_num  ...  \
# 0                  9         19               56562             1  ...
# 1                  9         19               56562             1  ...
# 2                  9         19               56562             0  ...
# 3                  9         19               56562             1  ...
# 4                  9         19               56562             9  ...
# 5                  9         19               56562             0  ...
# 6                  9         19               56562             0  ...
# 7                  9         19               56562             9  ...
# 8                  9         19               56562             9  ...
# 9                  9         19               56562             0  ...
# 10                 9         19               56562             0  ...
#
#     coupon_use  purchase_price  unit_price_category  purchase_price_average  \
# 0            0             534                  267                    6284
# 1            0            2803                 1401                    6284
# 2            0               0                    0                    6284
# 3            0             764                  764                    6284
# 4            0            4981                  293                    6284
# 5            0               0                    0                    6284
# 6            0               0                    0                    6284
# 7            0           22620                  293                    6284
# 8            0           24860                 2486                    6284
# 9            0               0                    0                    6284
# 10           0               0                    0                    6284
#
#     visit_cycle  ratio_category  adult_num  purchase_price_category_average  \
# 0             4        0.009441          1                              267
# 1             4        0.049556          1                             1401
# 2             4        0.000000          1                                0
# 3             4        0.013507          1                              764
# 4             4        0.088063          1                              293
# 5             4        0.000000          1                                0
# 6             4        0.000000          1                                0
# 7             4        0.399915          1                              293
# 8             4        0.439518          1                             2486
# 9             4        0.000000          1                                0
# 10            4        0.000000          1                                0
#
#     purchase_price_1person  purchase_price_1day
# 0                    56562                 1346
# 1                    56562                 1346
# 2                    56562                 1346
# 3                    56562                 1346
# 4                    56562                 1346
# 5                    56562                 1346
# 6                    56562                 1346
# 7                    56562                 1346
# 8                    56562                 1346
# 9                    56562                 1346
# 10                   56562                 1346
#
# [11 rows x 21 columns]

# %%
#LightGBMによるモデル作成
train_x = train_data.drop(['coupon_use_result','uuid'], axis=1)
train_y = train_data[['coupon_use_result']]
val_size = 4
uuid_num = train_data['uuid'].nunique()
train_uuid = int((uuid_num/val_size)*(val_size-1))
filter_idx = (train_uuid*11)-1
tr_x, va_x = train_x.iloc[:filter_idx], train_x.iloc[filter_idx:]
tr_y, va_y = train_y.iloc[:filter_idx], train_y.iloc[filter_idx:]

# params = {'objective': 'binary',
#          'metric': 'binary_logloss',
#          'seed': 70,
#          'feature_pre_filter': False,
#          'lambda_l1': 0.7363266301419099,
#          'lambda_l2': 0.0012895602337976008,
#          'num_leaves': 5,
#          'feature_fraction': 0.552,
#          'bagging_fraction': 0.5443702579911031,
#          'bagging_freq': 5,
#          'min_data_in_leaf': 20,
#          'min_child_samples': 20}
# params = {'objective': 'binary',
#          'metric': 'binary_logloss',
#          'seed': 71,
#          'feature_pre_filter': False,
#          'lambda_l1': 0.00000005204866804465978,
#          'lambda_l2': 0.00003133667635701077,
#          'num_leaves': 317,
#          'feature_fraction': 0.848640913268004,
#          'bagging_fraction': 0.4983467582046316,
#          'bagging_freq': 4,
#          'min_child_samples': 22}

score_dict = {}
# for i in range(200):
params = {'objective': 'binary',
         'metric': 'binary_logloss',
         'seed': 118,
         'lambda_l1': 0.00416566836241902,
         'lambda_l2': 0.10371698288325823,
         'num_leaves': 333,
         'feature_fraction': 0.6873251818776734,
         'bagging_fraction': 0.6363448284692337,
         'bagging_freq': 10,
         'min_child_samples': 17
        }

num_round =1000
# categorical_feature = ['marry_flg','age']
scores = []

lgb_train = lgb.Dataset(tr_x, tr_y)
lgb_eval = lgb.Dataset(va_x, va_y)

best_params, tuning_history = dict(), list()
model = lgb.train(params, 
                  lgb_train, 
                  verbose_eval=50,  # 50イテレーション毎に学習結果出力
#                   categorical_feature = categorical_feature,
                  num_boost_round=num_round, 
                  early_stopping_rounds=100,
                  valid_names=['train', 'valid'], 
                  valid_sets=[lgb_train, lgb_eval]
                 )

va_pred = model.predict(va_x)
score = log_loss(va_y, va_pred)
scores.append(score)
# score_dict[i] = score
#     print("="*80)

print("平均logloss：",np.mean(scores))
# Out:
# Training until validation scores don't improve for 100 rounds
# [50]	train's binary_logloss: 0.00989969	valid's binary_logloss: 0.0595462
# [100]	train's binary_logloss: 0.00254294	valid's binary_logloss: 0.0726514
# Early stopping, best iteration is:
# [13]	train's binary_logloss: 0.0378827	valid's binary_logloss: 0.0486878
# 平均logloss： 0.04868782829132765

# %%
score_dict
# Out:
# {}

# %%
scores
# Out:
# [0.04868782829132765]

# %%
#テストデータの予測
pred = model.predict(test_data.drop('uuid',axis=1))
pred = pd.Series(pred, name='pred')

# %%
# 特徴量重要度の算出 (データフレームで取得)
cols = list(train_x.columns)         # 特徴量名のリスト
f_importance = np.array(model.feature_importance()) # 特徴量重要度の算出
f_importance = f_importance / np.sum(f_importance)  # 正規化(必要ない場合はコメントアウト)
df_importance = pd.DataFrame({'feature':cols, 'importance':f_importance})
df_importance = df_importance.sort_values('importance', ascending=False) # 降順ソート
display(df_importance)
# Out:
#                             feature  importance
# 10                   purchase_price    0.101770
# 6                all_purchase_price    0.088496
# 8              purchase_product_num    0.088496
# 11              unit_price_category    0.088496
# 5                         pass_days    0.084071
# 17           purchase_price_1person    0.070796
# 0                         coupon_id    0.061947
# 14                   ratio_category    0.061947
# 4                  visits_frequency    0.061947
# 12           purchase_price_average    0.061947
# 18              purchase_price_1day    0.044248
# 3                            income    0.044248
# 7                      purchase_num    0.030973
# 16  purchase_price_category_average    0.030973
# 1                       fammily_num    0.026549
# 9                        coupon_use    0.026549
# 2                         child_num    0.017699
# 13                      visit_cycle    0.004425
# 15                        adult_num    0.004425

# %%
pred
# Out:
# 0       0.003726
# 1       0.003726
# 2       0.003726
# 3       0.003726
# 4       0.010019
#           ...
# 3911    0.007258
# 3912    0.010778
# 3913    0.009631
# 3914    0.009631
# 3915    0.017302
# Name: pred, Length: 3916, dtype: float64

# %%
def round_score(pred):
    if pred <= 0.0056:
        pred = 0
    elif pred >= 0.9944:
        pred = 1
    return pred

# %%
pred = pred.apply(lambda x: round_score(x))
result = test_data.join(pred)[['uuid', 'coupon_id', 'pred']]
result = result.pivot(index='uuid', columns='coupon_id', values='pred')

# %%
pred.min()
# Out:
# 0.0

# %%
pred.max()
# Out:
# 0.4040067200215342

# %%
result
# Out:
# coupon_id        1         2         3         4         5         6   \
# uuid
# 357        0.000000  0.000000  0.000000  0.000000  0.010019  0.000000
# 358        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 359        0.023098  0.011099  0.000000  0.007920  0.008600  0.000000
# 360        0.000000  0.006747  0.000000  0.000000  0.000000  0.000000
# 361        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...             ...       ...       ...       ...       ...       ...
# 708        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 709        0.005654  0.000000  0.000000  0.007445  0.000000  0.000000
# 710        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 711        0.083603  0.008435  0.016646  0.031668  0.020388  0.011044
# 712        0.007258  0.007258  0.007258  0.000000  0.007258  0.007258
#
# coupon_id        7         8         9         10        11
# uuid
# 357        0.000000  0.019228  0.000000  0.000000  0.000000
# 358        0.000000  0.053306  0.038012  0.019076  0.019541
# 359        0.005723  0.404007  0.014478  0.000000  0.006285
# 360        0.000000  0.006771  0.000000  0.000000  0.000000
# 361        0.000000  0.012730  0.000000  0.000000  0.000000
# ...             ...       ...       ...       ...       ...
# 708        0.000000  0.029154  0.000000  0.000000  0.007670
# 709        0.007786  0.028291  0.016769  0.011618  0.012511
# 710        0.000000  0.000000  0.000000  0.000000  0.000000
# 711        0.036315  0.283974  0.023186  0.008781  0.014161
# 712        0.007258  0.010778  0.009631  0.009631  0.017302
#
# [356 rows x 11 columns]

# %%
result.to_csv('/Users/atsushisato/git_clone/ai_quest_season2/models/model.csv',header=False)

# %%
pred.nunique()
# Out:
# 1083

# %% [markdown]
# # optunaによるパラメータ調整

# %%
model.params
# Out:
# {'objective': 'binary',
#  'metric': 'binary_logloss',
#  'seed': 71,
#  'feature_pre_filter': False,
#  'lambda_l1': 1.0075794784727784e-08,
#  'lambda_l2': 0.023033986719849988,
#  'num_leaves': 317,
#  'feature_fraction': 0.7,
#  'bagging_fraction': 0.4983467582046316,
#  'bagging_freq': 4,
#  'min_data_in_leaf': 22,
#  'min_child_samples': 20}

# %%
# パラメータ調整用

# prediction = np.rint(model.predict(va_x, num_iteration=model.best_iteration))
# accuracy = accuracy_score(va_y, prediction)

# best_params = model.params
# print("Best params:", display(best_params)
# print("  Accuracy = {}".format(accuracy))
# print("  Params: ")
# for key, value in best_params.items():
#     print("    {}: {}".format(key, value))
# Out:
#   File "<ipython-input-15-7e011e4073ba>", line 8
#     print("  Accuracy = {}".format(accuracy))
#         ^
# SyntaxError: invalid syntax

# %%
def objective(trial):
    param = {
        'objective': 'binary',
        'metric': 'binary_logloss',
        'boosting': 'gbdt',
        'learning_rate': 0.05,
        'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
        'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
        'num_leaves': trial.suggest_int('num_leaves', 2, 512),
        'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
        'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 0, 10),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'seed': 0,
        'verbosity': -1,
    }
    gbm = lgb.train(param, 
                    lgb_train, 
                    valid_sets=lgb_eval,
                    verbose_eval=False, 
                    num_boost_round=num_round, 
                    early_stopping_rounds=100
                   )
    y_prob = gbm.predict(va_x)
    y_pred = np.round(y_prob)
    return roc_auc_score(
        np.round(va_y.values),
        np.round(y_pred)
    )

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2021-01-05 09:32:08,411] A new study created in memory with name: no-name-31afc2b9-8c57-4741-9a2f-6ee37022fa06
# [I 2021-01-05 09:32:08,414] A new study created in memory with name: no-name-e53365cc-6254-4fae-b234-5490531e8d3c
# feature_fraction, val_score: 0.052296:  14%|#4        | 1/7 [00:00<00:00,  7.16it/s][I 2021-01-05 09:32:08,557] Trial 0 finished with value: 0.05229556804139281 and parameters: {'feature_fraction': 0.8}. Best is trial 0 with value: 0.05229556804139281.
# feature_fraction, val_score: 0.050982:  29%|##8       | 2/7 [00:00<00:00,  7.44it/s][I 2021-01-05 09:32:08,679] Trial 1 finished with value: 0.05098198266465183 and parameters: {'feature_fraction': 0.7}. Best is trial 1 with value: 0.05098198266465183.
# feature_fraction, val_score: 0.050928:  43%|####2     | 3/7 [00:00<00:00,  7.46it/s][I 2021-01-05 09:32:08,812] Trial 2 finished with value: 0.05092779476426663 and parameters: {'feature_fraction': 0.6}. Best is trial 2 with value:
. Best is trial 19 with value: 0.04903048290369846.
# num_leaves, val_score: 0.049030:  80%|########  | 16/20 [00:01<00:00, 10.90it/s][I 2021-01-05 09:32:11,132] Trial 22 finished with value: 0.04903048290369846 and parameters: {'num_leaves': 2}. Best is trial 19 with value: 0.04903048290369846.
# num_leaves, val_score: 0.049030:  80%|########  | 16/20 [00:01<00:00, 10.90it/s][I 2021-01-05 09:32:11,228] Trial 23 finished with value: 0.05066290760526527 and parameters: {'num_leaves': 55}. Best is trial 19 with value: 0.04903048290369846.
# num_leaves, val_score: 0.049030:  90%|######### | 18/20 [00:01<00:00, 11.57it/s][I 2021-01-05 09:32:11,279] Trial 24 finished with value: 0.05177882037666502 and parameters: {'num_leaves': 8}. Best is trial 19 with value: 0.04903048290369846.
# num_leaves, val_score: 0.049030:  90%|######### | 18/20 [00:02<00:00, 11.57it/s][I 2021-01-05 09:32:11,392] Trial 25 finished with value: 0.05066290760526527 and parameters: {'num_leaves': 69}. Best is trial 19 with value: 0.04903048290369846.
# num_leaves, val_score: 0.049030: 100%|##########| 20/20 [00:02<00:00, 10.36it/s][I 2021-01-05 09:32:11,520] Trial 26 finished with value: 0.05061589720432755 and parameters: {'num_leaves': 24}. Best is trial 19 with value: 0.04903048290369846.
# num_leaves, val_score: 0.049030: 100%|##########| 20/20 [00:02<00:00,  9.18it/s]
# bagging, val_score: 0.049030:   0%|          | 0/10 [00:00<?, ?it/s][I 2021-01-05 09:32:11,566] Trial 27 finished with value: 0.049695253865250484 and parameters: {'bagging_fraction': 0.7303471274685067, 'bagging_freq': 6}. Best is trial 27 with value: 0.049695253865250484.
# bagging, val_score: 0.049030:  10%|#         | 1/10 [00:00<00:00, 11.21it/s][I 2021-01-05 09:32:11,614] Trial 28 finished with value: 0.04986931990508196 and parameters: {'bagging_fraction': 0.4410625686895766, 'bagging_freq': 2}. Best is trial 27 with value: 0.049695253865250484.
# bagging, val_score: 0.049030:  30%|###       | 3/10 [00:00<00:00, 23.14it/s][I 2021-01-05 09:32:11,655] Trial 29 finished with value: 0.049871134942517145 and parameters: {'bagging_fraction': 0.9758314217046181, 'bagging_freq': 7}. Best is trial 27 with value: 0.049695253865250484.
# bagging, val_score: 0.049030:  30%|###       | 3/10 [00:00<00:00, 23.14it/s][I 2021-01-05 09:32:11,705] Trial 30 finished with value: 0.050019822310699694 and parameters: {'bagging_fraction': 0.4070234773491737, 'bagging_freq': 1}. Best is trial 27 with value: 0.049695253865250484.
# bagging, val_score: 0.049030:  40%|####      | 4/10 [00:00<00:00, 23.14it/s][I 2021-01-05 09:32:11,753] Trial 31 finished with value: 0.050047016415436685 and parameters: {'bagging_fraction': 0.7617103804016497, 'bagging_freq': 6}. Best is trial 27 with value: 0.049695253865250484.
# bagging, val_score: 0.049030:  60%|######    | 6/10 [00:00<00:00, 22.81it/s][I 2021-01-05 09:32:11,790] Trial 32 finished with value: 0.04966986811862851 and parameters: {'bagging_fraction': 0.6917837968581766, 'bagging_freq': 5}. Best is trial 32 with value: 0.04966986811862851.
# bagging, val_score: 0.048235:  60%|######    | 6/10 [00:00<00:00, 22.81it/s][I 2021-01-05 09:32:11,832] Trial 33 finished with value: 0.04823461420516611 and parameters: {'bagging_fraction': 0.5707475512545257, 'bagging_freq': 4}. Best is trial 33 with value: 0.04823461420516611.
# bagging, val_score: 0.048235:  70%|#######   | 7/10 [00:00<00:00, 22.81it/s][I 2021-01-05 09:32:11,870] Trial 34 finished with value: 0.04921647177586318 and parameters: {'bagging_fraction': 0.5486693278499071, 'bagging_freq': 3}. Best is trial 33 with value: 0.04823461420516611.
# bagging, val_score: 0.048235:  90%|######### | 9/10 [00:00<00:00, 23.47it/s][I 2021-01-05 09:32:11,910] Trial 35 finished with value: 0.04919849681907557 and parameters: {'bagging_fraction': 0.561453439901609, 'bagging_freq': 3}. Best is trial 33 with value: 0.04823461420516611.
# bagging, val_score: 0.048235:  90%|######### | 9/10 [00:00<00:00, 23.47it/s][I 2021-01-05 09:32:11,948] Trial 36 finished with value: 0.04833983065375569 and parameters: {'bagging_fraction': 0.5792949011600752, 'bagging_freq': 4}. Best is trial 33 with value: 0.04823461420516611.
# bagging, val_score: 0.048235: 100%|##########| 10/10 [00:00<00:00, 23.54it/s]
# feature_fraction_stage2, val_score: 0.048235:   0%|          | 0/6 [00:00<?, ?it/s][I 2021-01-05 09:32:11,993] Trial 37 finished with value: 0.04835439429287642 and parameters: {'feature_fraction': 0.484}. Best is trial 37 with value: 0.04835439429287642.
# feature_fraction_stage2, val_score: 0.048235:  17%|#6        | 1/6 [00:00<00:00, 11.76it/s][I 2021-01-05 09:32:12,037] Trial 38 finished with value: 0.04823461420516611 and parameters: {'feature_fraction': 0.516}. Best is trial 38 with value: 0.04823461420516611.
# feature_fraction_stage2, val_score: 0.048235:  50%|#####     | 3/6 [00:00<00:00, 23.57it/s][I 2021-01-05 09:32:12,079] Trial 39 finished with value: 0.04823461420516611 and parameters: {'feature_fraction': 0.5479999999999999}. Best is trial 38 with value: 0.04823461420516611.
# feature_fraction_stage2, val_score: 0.048235:  50%|#####     | 3/6 [00:00<00:00, 23.57it/s][I 2021-01-05 09:32:12,120] Trial 40 finished with value: 0.0483800210400422 and parameters: {'feature_fraction': 0.58}. Best is trial 38 with value: 0.04823461420516611.
# feature_fraction_stage2, val_score: 0.048235:  67%|######6   | 4/6 [00:00<00:00, 23.57it/s][I 2021-01-05 09:32:12,160] Trial 41 finished with value: 0.04832734675765569 and parameters: {'feature_fraction': 0.42}. Best is trial 38 with value: 0.04823461420516611.
# feature_fraction_stage2, val_score: 0.048235: 100%|##########| 6/6 [00:00<00:00, 24.05it/s][I 2021-01-05 09:32:12,198] Trial 42 finished with value: 0.04835439429287642 and parameters: {'feature_fraction': 0.45199999999999996}. Best is trial 38 with value: 0.04823461420516611.
# feature_fraction_stage2, val_score: 0.048235: 100%|##########| 6/6 [00:00<00:00, 24.15it/s]
# regularization_factors, val_score: 0.048209:   0%|          | 0/20 [00:00<?, ?it/s][I 2021-01-05 09:32:12,245] Trial 43 finished with value: 0.04820915252539915 and parameters: {'lambda_l1': 2.0613576870261178e-07, 'lambda_l2': 1.421930495019248e-07}. Best is trial 43 with value: 0.04820915252539915.
# regularization_factors, val_score: 0.048209:   5%|5         | 1/20 [00:00<00:01, 12.78it/s][I 2021-01-05 09:32:12,281] Trial 44 finished with value: 0.04820915236692681 and parameters: {'lambda_l1': 8.945488232112026e-08, 'lambda_l2': 2.8558809119229105e-08}. Best is trial 44 with value: 0.04820915236692681.
# regularization_factors, val_score: 0.048209:  15%|#5        | 3/20 [00:00<00:00, 25.99it/s][I 2021-01-05 09:32:12,319] Trial 45 finished with value: 0.048209152358602056 and parameters: {'lambda_l1': 6.334105605272813e-08, 'lambda_l2': 2.8478948561236136e-08}. Best is trial 45 with value: 0.048209152358602056.
# regularization_factors, val_score: 0.048209:  15%|#5        | 3/20 [00:00<00:00, 25.99it/s][I 2021-01-05 09:32:12,356] Trial 46 finished with value: 0.04820915235463273 and parameters: {'lambda_l1': 4.348296225934916e-08, 'lambda_l2': 3.049737502702138e-08}. Best is trial 46 with value: 0.04820915235463273.
# regularization_factors, val_score: 0.048209:  20%|##        | 4/20 [00:00<00:00, 25.99it/s][I 2021-01-05 09:32:12,393] Trial 47 finished with value: 0.04820915235763031 and parameters: {'lambda_l1': 5.8791256660846585e-08, 'lambda_l2': 2.9209247259280984e-08}. Best is trial 46 with value: 0.04820915235463273.
# regularization_factors, val_score: 0.048209:  30%|###       | 6/20 [00:00<00:00, 25.31it/s][I 2021-01-05 09:32:12,444] Trial 48 finished with value: 0.048209152332185506 and parameters: {'lambda_l1': 3.867799132057908e-08, 'lambda_l2': 2.1394087344818733e-08}. Best is trial 48 with value: 0.048209152332185506.
# regularization_factors, val_score: 0.048209:  30%|###       | 6/20 [00:00<00:00, 25.31it/s][I 2021-01-05 09:32:12,483] Trial 49 finished with value: 0.04820915233045257 and parameters: {'lambda_l1': 4.314173728450066e-08, 'lambda_l2': 1.986942974807688e-08}. Best is trial 49 with value: 0.04820915233045257.
# regularization_factors, val_score: 0.048209:  35%|###5      | 7/20 [00:00<00:00, 25.31it/s][I 2021-01-05 09:32:12,521] Trial 50 finished with value: 0.04820915233287935 and parameters: {'lambda_l1': 3.227641757855432e-08, 'lambda_l2': 2.2652921995645036e-08}. Best is trial 49 with value: 0.04820915233045257.
# regularization_factors, val_score: 0.048209:  45%|####5     | 9/20 [00:00<00:00, 24.39it/s][I 2021-01-05 09:32:12,578] Trial 51 finished with value: 0.048209152338015045 and parameters: {'lambda_l1': 5.420830702455372e-08, 'lambda_l2': 2.0034351515301823e-08}. Best is trial 49 with value: 0.04820915233045257.
# regularization_factors, val_score: 0.048209:  45%|####5     | 9/20 [00:00<00:00, 24.39it/s][I 2021-01-05 09:32:12,616] Trial 52 finished with value: 0.04820915233177738 and parameters: {'lambda_l1': 3.22914197645571e-08, 'lambda_l2': 2.2242932675021544e-08}. Best is trial 49 with value: 0.04820915233045257.
# regularization_factors, val_score: 0.048209:  50%|#####     | 10/20 [00:00<00:00, 24.39it/s][I 2021-01-05 09:32:12,656] Trial 53 finished with value: 0.048209152325883284 and parameters: {'lambda_l1': 1.3194440603442577e-08, 'lambda_l2': 2.361096638735111e-08}. Best is trial 53 with value: 0.048209152325883284.
# regularization_factors, val_score: 0.048209:  60%|######    | 12/20 [00:00<00:00, 24.81it/s][I 2021-01-05 09:32:12,694] Trial 54 finished with value: 0.04820915233240778 and parameters: {'lambda_l1': 1.3447092173837057e-08, 'lambda_l2': 1.7637831662386155e-08}. Best is trial 53 with value: 0.048209152325883284.
# regularization_factors, val_score: 0.048209:  60%|######    | 12/20 [00:00<00:00, 24.81it/s][I 2021-01-05 09:32:12,733] Trial 55 finished with value: 0.04820915231875733 and parameters: {'lambda_l1': 1.095841758250264e-08, 'lambda_l2': 1.106622085892639e-08}. Best is trial 55 with value: 0.04820915231875733.
# regularization_factors, val_score: 0.048209:  65%|######5   | 13/20 [00:00<00:00, 24.81it/s][I 2021-01-05 09:32:12,775] Trial 56 finished with value: 0.048877441668510574 and parameters: {'lambda_l1': 0.18897912454239596, 'lambda_l2': 2.0143920242448607}. Best is trial 55 with value: 0.04820915231875733.
# regularization_factors, val_score: 0.048209:  75%|#######5  | 15/20 [00:00<00:00, 24.89it/s][I 2021-01-05 09:32:12,813] Trial 57 finished with value: 0.048209156635869437 and parameters: {'lambda_l1': 1.311102626311306e-08, 'lambda_l2': 3.508945617472427e-06}. Best is trial 55 with value: 0.04820915231875733.
# regularization_factors, val_score: 0.048209:  75%|#######5  | 15/20 [00:00<00:00, 24.89it/s][I 2021-01-05 09:32:12,852] Trial 58 finished with value: 0.04820915466231445 and parameters: {'lambda_l1': 3.107951640882943e-06, 'lambda_l2': 1.1441871171525322e-06}. Best is trial 55 with value: 0.04820915231875733.
# regularization_factors, val_score: 0.048209:  80%|########  | 16/20 [00:00<00:00, 24.89it/s][I 2021-01-05 09:32:12,891] Trial 59 finished with value: 0.04820915231769938 and parameters: {'lambda_l1': 1.3031850801945632e-08, 'lambda_l2': 1.036760243281831e-08}. Best is trial 59 with value: 0.04820915231769938.
# regularization_factors, val_score: 0.048209:  90%|######### | 18/20 [00:00<00:00, 25.16it/s][I 2021-01-05 09:32:12,930] Trial 60 finished with value: 0.048209153373590496 and parameters: {'lambda_l1': 9.041491736671687e-07, 'lambda_l2': 6.446114225396912e-07}. Best is trial 59 with value: 0.04820915231769938.
# regularization_factors, val_score: 0.048209:  90%|######### | 18/20 [00:00<00:00, 25.16it/s][I 2021-01-05 09:32:12,968] Trial 61 finished with value: 0.048209152320195535 and parameters: {'lambda_l1': 1.172770016956726e-08, 'lambda_l2': 1.1413958979868421e-08}. Best is trial 59 with value: 0.04820915231769938.
# regularization_factors, val_score: 0.048209:  95%|#########5| 19/20 [00:00<00:00, 25.16it/s][I 2021-01-05 09:32:13,009] Trial 62 finished with value: 0.048209152319812223 and parameters: {'lambda_l1': 1.0950587158175052e-08, 'lambda_l2': 1.1349602011107014e-08}. Best is trial 59 with value: 0.04820915231769938.
# regularization_factors, val_score: 0.048209: 100%|##########| 20/20 [00:00<00:00, 24.77it/s]
# min_data_in_leaf, val_score: 0.048209:   0%|          | 0/5 [00:00<?, ?it/s][I 2021-01-05 09:32:13,056] Trial 63 finished with value: 0.04820915231769938 and parameters: {'min_child_samples': 100}. Best is trial 63 with value: 0.04820915231769938.
# min_data_in_leaf, val_score: 0.048209:  20%|##        | 1/5 [00:00<00:00, 11.96it/s][I 2021-01-05 09:32:13,096] Trial 64 finished with value: 0.04820915231769938 and parameters: {'min_child_samples': 5}. Best is trial 63 with value: 0.04820915231769938.
# min_data_in_leaf, val_score: 0.048209:  60%|######    | 3/5 [00:00<00:00, 23.90it/s][I 2021-01-05 09:32:13,138] Trial 65 finished with value: 0.04820915231769938 and parameters: {'min_child_samples': 50}. Best is trial 63 with value: 0.04820915231769938.
# min_data_in_leaf, val_score: 0.048209:  60%|######    | 3/5 [00:00<00:00, 23.90it/s][I 2021-01-05 09:32:13,180] Trial 66 finished with value: 0.04820915231769938 and parameters: {'min_child_samples': 25}. Best is trial 63 with value: 0.04820915231769938.
# min_data_in_leaf, val_score: 0.048209:  80%|########  | 4/5 [00:00<00:00, 23.90it/s][I 2021-01-05 09:32:13,221] Trial 67 finished with value: 0.04820915231769938 and parameters: {'min_child_samples': 10}. Best is trial 63 with value: 0.04820915231769938.
# min_data_in_leaf, val_score: 0.048209: 100%|##########| 5/5 [00:00<00:00, 23.78it/s]
# [I 2021-01-05 09:32:13,228] Trial 0 finished with value: 0.5 and parameters: {'lambda_l1': 0.00416566836241902, 'lambda_l2': 0.10371698288325823, 'num_leaves': 333, 'feature_fraction': 0.6873251818776734, 'bagging_fraction': 0.6363448284692337, 'bagging_freq': 10, 'min_child_samples': 17}. Best is trial 0 with value: 0.5.
# [I 2021-01-05 09:32:13,229] A new study created in memory with name: no-name-a1f29e75-2664-4e1b-872f-55959ebad012
# feature_fraction, val_score: 0.052418:  14%|#4        | 1/7 [00:00<00:01,  5.10it/s][I 2021-01-05 09:32:13,430] Trial 0 finished with value: 0.05241801492287328 and parameters: {'feature_fraction': 0.6}. Best is trial 0 with value: 0.05241801492287328.
# feature_fraction, val_score: 0.052228:  29%|##8       | 2/7 [00:00<00:00,  5.64it/s][I 2021-01-05 09:32:13,563] Trial 1 finished with value: 0.05222750647691235 and parameters: {'feature_fraction': 0.7}. Best is trial 1 with value: 0.05222750647691235.
# feature_fraction, val_score: 0.052228:  43%|####2     | 3/7 [00:00<00:00,  6.24it/s][I 2021-01-05 09:32:13,684] Trial 2 finished with value: 0.05237522934070156 and parameters: {'feature_fraction': 0.5}. Best is trial 1 with value: 0.05222750647691235.
# feature_fraction, val_score: 0.052054:  57%|#####7    | 4/7 [00:00<00:00,  6.63it/s][I 2021-01-05 09:32:13,813] Trial 3 finished with value: 0.05205398640868835 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 3 with value: 0.05205398640868835.
# feature_fraction, val_score: 0.051199:  71%|#######1  | 5/7 [00:00<00:00,  7.18it/s][I 2021-01-05 09:32:13,925] Trial 4 finished with value: 0.05119881668606704 and parameters: {'feature_fraction': 0.4}. Best is trial 4 with value: 0.05119881668606704.
# feature_fraction, val_score: 0.051199:  86%|########5 | 6/7 [00:00<00:00,  7.02it/s][I 2021-01-05 09:32:14,075] Trial 5 finished with value: 0.05188989067970822 and parameters: {'feature_fraction': 0.8}. Best is trial 4 with value: 0.05119881668606704.
# feature_fraction, val_score: 0.051199: 100%|##########| 7/7 [00:00<00:00,  7.16it/s][I 2021-01-05 09:32:14,208] Trial 6 finished with value: 0.0513918162271426 and parameters: {'feature_fraction': 1.0}. Best is trial 4 with value: 0.05119881668606704.
# feature_fraction, val_score: 0.051199: 100%|##########| 7/7 [00:00<00:00,  7.17it/s]
# num_leaves, val_score: 0.051199:   5%|5         | 1/20 [00:00<00:02,  8.89it/s][I 2021-01-05 09:32:14,325] Trial 7 finished with value: 0.05119881668606704 and parameters: {'num_leaves':
. Best is trial 15 with value: 0.050049699717392496.
# num_leaves, val_score: 0.050050:  90%|######### | 18/20 [00:01<00:00, 11.45it/s][I 2021-01-05 09:32:15,877] Trial 25 finished with value: 0.05119893605914714 and parameters: {'num_leaves': 33}. Best is trial 15 with value: 0.050049699717392496.
# num_leaves, val_score: 0.050050: 100%|##########| 20/20 [00:01<00:00, 10.70it/s][I 2021-01-05 09:32:15,990] Trial 26 finished with value: 0.05119881668606704 and parameters: {'num_leaves': 142}. Best is trial 15 with value: 0.050049699717392496.
# num_leaves, val_score: 0.050050: 100%|##########| 20/20 [00:01<00:00, 11.24it/s]
# bagging, val_score: 0.048998:   0%|          | 0/10 [00:00<?, ?it/s][I 2021-01-05 09:32:16,040] Trial 27 finished with value: 0.048997583469500484 and parameters: {'bagging_fraction': 0.6343611581319327, 'bagging_freq': 6}. Best is trial 27 with value: 0.048997583469500484.
# bagging, val_score: 0.048934:  10%|#         | 1/10 [00:00<00:00, 11.78it/s][I 2021-01-05 09:32:16,080] Trial 28 finished with value: 0.04893375826945045 and parameters: {'bagging_fraction': 0.6225354663326415, 'bagging_freq': 6}. Best is trial 28 with value: 0.04893375826945045.
# bagging, val_score: 0.048934:  30%|###       | 3/10 [00:00<00:00, 24.45it/s][I 2021-01-05 09:32:16,118] Trial 29 finished with value: 0.04893866166447069 and parameters: {'bagging_fraction': 0.627869857853744, 'bagging_freq': 6}. Best is trial 28 with value: 0.04893375826945045.
# bagging, val_score: 0.048934:  30%|###       | 3/10 [00:00<00:00, 24.45it/s][I 2021-01-05 09:32:16,158] Trial 30 finished with value: 0.04899234477881581 and parameters: {'bagging_fraction': 0.6258639954767768, 'bagging_freq': 6}. Best is trial 28 with value: 0.04893375826945045.
# bagging, val_score: 0.048874:  40%|####      | 4/10 [00:00<00:00, 24.45it/s][I 2021-01-05 09:32:16,196] Trial 31 finished with value: 0.04887380422167832 and parameters: {'bagging_fraction': 0.6192615335288283, 'bagging_freq': 6}. Best is trial 31 with value: 0.04887380422167832.
# bagging, val_score: 0.048874:  60%|######    | 6/10 [00:00<00:00, 24.75it/s][I 2021-01-05 09:32:16,235] Trial 32 finished with value: 0.04893866166447069 and parameters: {'bagging_fraction': 0.6272603102682786, 'bagging_freq': 6}. Best is trial 31 with value: 0.04887380422167832.
# bagging, val_score: 0.048873:  60%|######    | 6/10 [00:00<00:00, 24.75it/s][I 2021-01-05 09:32:16,275] Trial 33 finished with value: 0.04887333453224394 and parameters: {'bagging_fraction': 0.6184705230377633, 'bagging_freq': 6}. Best is trial 33 with value: 0.04887333453224394.
# bagging, val_score: 0.048666:  70%|#######   | 7/10 [00:00<00:00, 24.75it/s][I 2021-01-05 09:32:16,312] Trial 34 finished with value: 0.04866554909277844 and parameters: {'bagging_fraction': 0.6115188520290419, 'bagging_freq': 6}. Best is trial 34 with value: 0.04866554909277844.
# bagging, val_score: 0.048666:  90%|######### | 9/10 [00:00<00:00, 25.09it/s][I 2021-01-05 09:32:16,351] Trial 35 finished with value: 0.04875984083998324 and parameters: {'bagging_fraction': 0.4639955215952906, 'bagging_freq': 4}. Best is trial 34 with value: 0.04866554909277844.
# bagging, val_score: 0.048666:  90%|######### | 9/10 [00:00<00:00, 25.09it/s][I 2021-01-05 09:32:16,390] Trial 36 finished with value: 0.050647426674844585 and parameters: {'bagging_fraction': 0.4191059250770688, 'bagging_freq': 2}. Best is trial 34 with value: 0.04866554909277844.
# bagging, val_score: 0.048666: 100%|##########| 10/10 [00:00<00:00, 25.15it/s]
# feature_fraction_stage2, val_score: 0.048429:   0%|          | 0/3 [00:00<?, ?it/s][I 2021-01-05 09:32:16,434] Trial 37 finished with value: 0.04842876190973929 and parameters: {'feature_fraction': 0.44800000000000006}. Best is trial 37 with value: 0.04842876190973929.
# feature_fraction_stage2, val_score: 0.048429:  33%|###3      | 1/3 [00:00<00:00, 12.96it/s][I 2021-01-05 09:32:16,472] Trial 38 finished with value: 0.04866554909277844 and parameters: {'feature_fraction': 0.41600000000000004}. Best is trial 37 with value: 0.04842876190973929.
# feature_fraction_stage2, val_score: 0.048429: 100%|##########| 3/3 [00:00<00:00, 25.59it/s][I 2021-01-05 09:32:16,512] Trial 39 finished with value: 0.04842876190973929 and parameters: {'feature_fraction': 0.48000000000000004}. Best is trial 37 with value: 0.04842876190973929.
# feature_fraction_stage2, val_score: 0.048429: 100%|##########| 3/3 [00:00<00:00, 25.09it/s]
# regularization_factors, val_score: 0.048429:   0%|          | 0/20 [00:00<?, ?it/s][I 2021-01-05 09:32:16,582] Trial 40 finished with value: 0.048428750320541065 and parameters: {'lambda_l1': 1.3421960014944712e-08, 'lambda_l2': 7.763921339611704e-05}. Best is trial 40 with value: 0.048428750320541065.
# regularization_factors, val_score: 0.048429:  10%|#         | 2/20 [00:00<00:00, 18.91it/s][I 2021-01-05 09:32:16,623] Trial 41 finished with value: 0.048428751552566145 and parameters: {'lambda_l1': 1.1532223024210478e-08, 'lambda_l2': 6.681272034917657e-05}. Best is trial 40 with value: 0.048428750320541065.
# regularization_factors, val_score: 0.048429:  10%|#         | 2/20 [00:00<00:00, 18.91it/s][I 2021-01-05 09:32:16,665] Trial 42 finished with value: 0.048428754897603676 and parameters: {'lambda_l1': 1.4658018244095265e-08, 'lambda_l2': 3.7520709260663384e-05}. Best is trial 40 with value: 0.048428750320541065.
# regularization_factors, val_score: 0.048429:  15%|#5        | 3/20 [00:00<00:00, 18.91it/s][I 2021-01-05 09:32:16,706] Trial 43 finished with value: 0.04842874983255175 and parameters: {'lambda_l1': 1.2589952191568695e-08, 'lambda_l2': 8.190405319745894e-05}. Best is trial 43 with value: 0.04842874983255175.
# regularization_factors, val_score: 0.048429:  25%|##5       | 5/20 [00:00<00:00, 20.23it/s][I 2021-01-05 09:32:16,747] Trial 44 finished with value: 0.04842875333941544 and parameters: {'lambda_l1': 1.0689526156553006e-08, 'lambda_l2': 5.1182903835752544e-05}. Best is trial 43 with value: 0.04842874983255175.
# regularization_factors, val_score: 0.048429:  25%|##5       | 5/20 [00:00<00:00, 20.23it/s][I 2021-01-05 09:32:16,791] Trial 45 finished with value: 0.04842874950285473 and parameters: {'lambda_l1': 1.5128361119938212e-08, 'lambda_l2': 8.475834011962568e-05}. Best is trial 45 with value: 0.04842874950285473.
# regularization_factors, val_score: 0.048429:  30%|###       | 6/20 [00:00<00:00, 20.23it/s][I 2021-01-05 09:32:16,831] Trial 46 finished with value: 0.04842874967816986 and parameters: {'lambda_l1': 1.0418109982045459e-08, 'lambda_l2': 8.326979188529767e-05}. Best is trial 45 with value: 0.04842874950285473.
# regularization_factors, val_score: 0.048429:  40%|####      | 8/20 [00:00<00:00, 21.25it/s][I 2021-01-05 09:32:16,871] Trial 47 finished with value: 0.04842874616584543 and parameters: {'lambda_l1': 1.4680883615459012e-08, 'lambda_l2': 0.00011404551536286008}. Best is trial 47 with value: 0.04842874616584543.
# regularization_factors, val_score: 0.048429:  40%|####      | 8/20 [00:00<00:00, 21.25it/s][I 2021-01-05 09:32:16,914] Trial 48 finished with value: 0.04842874722413385 and parameters: {'lambda_l1': 1.4204600927459302e-08, 'lambda_l2': 0.00010468405009838383}. Best is trial 47 with value: 0.04842874616584543.
# regularization_factors, val_score: 0.048429:  45%|####5     | 9/20 [00:00<00:00, 21.25it/s][I 2021-01-05 09:32:16,954] Trial 49 finished with value: 0.04842873668972722 and parameters: {'lambda_l1': 1.3197376406471394e-08, 'lambda_l2': 0.00019708536812994425}. Best is trial 49 with value: 0.04842873668972722.
# regularization_factors, val_score: 0.048429:  55%|#####5    | 11/20 [00:00<00:00, 21.98it/s][I 2021-01-05 09:32:16,997] Trial 50 finished with value: 0.04845822343784571 and parameters: {'lambda_l1': 2.1610770960748517e-06, 'lambda_l2': 0.07288510752738295}. Best is trial 49 with value: 0.04842873668972722.
# regularization_factors, val_score: 0.048429:  55%|#####5    | 11/20 [00:00<00:00, 21.98it/s][I 2021-01-05 09:32:17,045] Trial 51 finished with value: 0.04842872024704402 and parameters: {'lambda_l1': 1.0427450055014346e-08, 'lambda_l2': 0.0003415242591176108}. Best is trial 51 with value: 0.04842872024704402.
# regularization_factors, val_score: 0.048429:  65%|######5   | 13/20 [00:00<00:00, 19.77it/s][I 2021-01-05 09:32:17,122] Trial 52 finished with value: 0.04860899161438702 and parameters: {'lambda_l1': 3.159032091560216, 'lambda_l2': 0.0016517727568740354}. Best is trial 51 with value: 0.04842872024704402.
# regularization_factors, val_score: 0.048429:  65%|######5   | 13/20 [00:00<00:00, 19.77it/s][I 2021-01-05 09:32:17,168] Trial 53 finished with value: 0.04842856952200944 and parameters: {'lambda_l1': 1.1523711654255626e-07, 'lambda_l2': 0.001688307564385004}. Best is trial 53 with value: 0.04842856952200944.
# regularization_factors, val_score: 0.048428:  70%|#######   | 14/20 [00:00<00:00, 19.77it/s][I 2021-01-05 09:32:17,212] Trial 54 finished with value: 0.04842837929009526 and parameters: {'lambda_l1': 5.554349043164376e-07, 'lambda_l2': 0.0034502921343229393}. Best is trial 54 with value: 0.04842837929009526.
# regularization_factors, val_score: 0.048428:  80%|########  | 16/20 [00:00<00:00, 20.52it/s][I 2021-01-05 09:32:17,255] Trial 55 finished with value: 0.048427995129314394 and parameters: {'lambda_l1': 1.5033479118450612e-06, 'lambda_l2': 0.007252026963028576}. Best is trial 55 with value: 0.048427995129314394.
# regularization_factors, val_score: 0.048428:  80%|########  | 16/20 [00:00<00:00, 20.52it/s][I 2021-01-05 09:32:17,302] Trial 56 finished with value: 0.04842776106589983 and parameters: {'lambda_l1': 1.643749806414447e-06, 'lambda_l2': 0.009758536987045603}. Best is trial 56 with value: 0.04842776106589983.
# regularization_factors, val_score: 0.048428:  85%|########5 | 17/20 [00:00<00:00, 20.52it/s][I 2021-01-05 09:32:17,346] Trial 57 finished with value: 0.04842752794890414 and parameters: {'lambda_l1': 2.536734496305071e-06, 'lambda_l2': 0.012435659204491425}. Best is trial 57 with value: 0.04842752794890414.
# regularization_factors, val_score: 0.048427:  95%|#########5| 19/20 [00:00<00:00, 21.05it/s][I 2021-01-05 09:32:17,389] Trial 58 finished with value: 0.048427385871918145 and parameters: {'lambda_l1': 2.286858852962742e-06, 'lambda_l2': 0.014169266002590138}. Best is trial 58 with value: 0.048427385871918145.
# regularization_factors, val_score: 0.048427:  95%|#########5| 19/20 [00:00<00:00, 21.05it/s][I 2021-01-05 09:32:17,457] Trial 59 finished with value: 0.04842728585179386 and parameters: {'lambda_l1': 1.6210084691230478e-06, 'lambda_l2': 0.015443173718640459}. Best is trial 59 with value: 0.04842728585179386.
# regularization_factors, val_score: 0.048427: 100%|##########| 20/20 [00:00<00:00, 21.22it/s]
# min_data_in_leaf, val_score: 0.048427:   0%|          | 0/5 [00:00<?, ?it/s][I 2021-01-05 09:32:17,513] Trial 60 finished with value: 0.04842728585179386 and parameters: {'min_child_samples': 50}. Best is trial 60 with value: 0.04842728585179386.
# min_data_in_leaf, val_score: 0.048427:  20%|##        | 1/5 [00:00<00:00, 10.18it/s][I 2021-01-05 09:32:17,560] Trial 61 finished with value: 0.04842728585179386 and parameters: {'min_child_samples': 100}. Best is trial 60 with value: 0.04842728585179386.
# min_data_in_leaf, val_score: 0.048427:  60%|######    | 3/5 [00:00<00:00, 20.60it/s][I 2021-01-05 09:32:17,607] Trial 62 finished with value: 0.04842728585179386 and parameters: {'min_child_samples': 5}. Best is trial 60 with value: 0.04842728585179386.
# min_data_in_leaf, val_score: 0.048427:  60%|######    | 3/5 [00:00<00:00, 20.60it/s][I 2021-01-05 09:32:17,657] Trial 63 finished with value: 0.04842728585179386 and parameters: {'min_child_samples': 25}. Best is trial 60 with value: 0.04842728585179386.
# min_data_in_leaf, val_score: 0.048427:  80%|########  | 4/5 [00:00<00:00, 20.60it/s][I 2021-01-05 09:32:17,703] Trial 64 finished with value: 0.04842728585179386 and parameters: {'min_child_samples': 10}. Best is trial 60 with value: 0.04842728585179386.
# min_data_in_leaf, val_score: 0.048427: 100%|##########| 5/5 [00:00<00:00, 20.52it/s]
# [I 2021-01-05 09:32:17,711] Trial 1 finished with value: 0.5 and parameters: {'lambda_l1': 1.3343444922945231e-05, 'lambda_l2': 1.651156274648374e-07, 'num_leaves': 219, 'feature_fraction': 0.8069640184196394, 'bagging_fraction': 0.9083438951212779, 'bagging_freq': 6, 'min_child_samples': 22}. Best is trial 0 with value: 0.5.
# [I 2021-01-05 09:32:17,713] A new study created in memory with name: no-name-43531e31-02e1-4e08-8bef-aaee2fe6332a
# feature_fraction, val_score: 0.051447:   0%|          | 0/7 [00:00<?, ?it/s][I 2021-01-05 09:32:17,805] Trial 0 finished with value: 0.05144668718768871 and parameters: {'feature_fraction': 0.8}. Best is trial 0 with value: 0
finished with value: 0.04874520189201964 and parameters: {'num_leaves': 75}. Best is trial 7 with value: 0.04874520189201964.
# num_leaves, val_score: 0.048745:  60%|######    | 12/20 [00:01<00:00, 11.60it/s][I 2021-01-05 09:32:19,481] Trial 19 finished with value: 0.04874520189201964 and parameters: {'num_leaves': 84}. Best is trial 7 with value: 0.04874520189201964.
# num_leaves, val_score: 0.048725:  70%|#######   | 14/20 [00:01<00:00, 11.90it/s][I 2021-01-05 09:32:19,555] Trial 20 finished with value: 0.04872522892842707 and parameters: {'num_leaves': 10}. Best is trial 20 with value: 0.04872522892842707.
# num_leaves, val_score: 0.048725:  70%|#######   | 14/20 [00:01<00:00, 11.90it/s][I 2021-01-05 09:32:19,633] Trial 21 finished with value: 0.04914986437948294 and parameters: {'num_leaves': 5}. Best is trial 20 with value: 0.04872522892842707.
# num_leaves, val_score: 0.048725:  80%|########  | 16/20 [00:01<00:00, 12.17it/s][I 2021-01-05 09:32:19,711] Trial 22 finished with value: 0.04874520189201964 and parameters: {'num_leaves': 103}. Best is trial 20 with value: 0.04872522892842707.
# num_leaves, val_score: 0.048725:  80%|########  | 16/20 [00:01<00:00, 12.17it/s][I 2021-01-05 09:32:20,013] Trial 23 finished with value: 0.04874520189201964 and parameters: {'num_leaves': 60}. Best is trial 20 with value: 0.04872522892842707.
# num_leaves, val_score: 0.048725:  90%|######### | 18/20 [00:01<00:00,  8.68it/s][I 2021-01-05 09:32:20,095] Trial 24 finished with value: 0.04874520189201964 and parameters: {'num_leaves': 112}. Best is trial 20 with value: 0.04872522892842707.
# num_leaves, val_score: 0.048725:  90%|######### | 18/20 [00:01<00:00,  8.68it/s][I 2021-01-05 09:32:20,184] Trial 25 finished with value: 0.04874520189201964 and parameters: {'num_leaves': 155}. Best is trial 20 with value: 0.04872522892842707.
# num_leaves, val_score: 0.048725: 100%|##########| 20/20 [00:01<00:00,  9.50it/s][I 2021-01-05 09:32:20,259] Trial 26 finished with value: 0.04874520189201964 and parameters: {'num_leaves': 53}. Best is trial 20 with value: 0.04872522892842707.
# num_leaves, val_score: 0.048725: 100%|##########| 20/20 [00:01<00:00, 10.48it/s]
# bagging, val_score: 0.048725:   0%|          | 0/10 [00:00<?, ?it/s][I 2021-01-05 09:32:20,342] Trial 27 finished with value: 0.051092887526577785 and parameters: {'bagging_fraction': 0.6997824580176987, 'bagging_freq': 7}. Best is trial 27 with value: 0.051092887526577785.
# bagging, val_score: 0.048725:  20%|##        | 2/10 [00:00<00:00, 13.68it/s][I 2021-01-05 09:32:20,411] Trial 28 finished with value: 0.04983317591546286 and parameters: {'bagging_fraction': 0.44056069562940176, 'bagging_freq': 1}. Best is trial 28 with value: 0.04983317591546286.
# bagging, val_score: 0.048725:  20%|##        | 2/10 [00:00<00:00, 13.68it/s][I 2021-01-05 09:32:20,483] Trial 29 finished with value: 0.05133586157934324 and parameters: {'bagging_fraction': 0.9875618683537126, 'bagging_freq': 4}. Best is trial 28 with value: 0.04983317591546286.
# bagging, val_score: 0.048725:  40%|####      | 4/10 [00:00<00:00, 13.86it/s][I 2021-01-05 09:32:20,551] Trial 30 finished with value: 0.05262753061873765 and parameters: {'bagging_fraction': 0.985279753688033, 'bagging_freq': 7}. Best is trial 28 with value: 0.04983317591546286.
# feature_fraction_stage2, val_score: 0.048319:  67%|######6   | 2/3 [00:00<00:00,  2.62it/s][I 2021-01-05 09:46:34,194] Trial 38 finished with value: 0.04831868728029626 and parameters: {'feature_fraction': 0.9840000000000001}. Best is trial 38 with value: 0.04831868728029626.
# feature_fraction_stage2, val_score: 0.047520: 100%|##########| 3/3 [00:01<00:00,  2.57it/s][I 2021-01-05 09:46:34,604] Trial 39 finished with value: 0.04752016651213944 and parameters: {'feature_fraction': 0.9520000000000001}. Best is trial 39 with value: 0.04752016651213944.
# feature_fraction_stage2, val_score: 0.047520: 100%|##########| 3/3 [00:01<00:00,  2.54it/s]
# regularization_factors, val_score: 0.047329:   5%|5         | 1/20 [00:00<00:08,  2.22it/s][I 2021-01-05 09:46:35,060] Trial 40 finished with value: 0.04732918655158931 and parameters: {'lambda_l1': 0.05272543245691199, 'lambda_l2': 1.1761078493698064e-06}. Best is trial 40 with value: 0.04732918655158931.
# regularization_factors, val_score: 0.047329:  10%|#         | 2/20 [00:00<00:07,  2.28it/s][I 2021-01-05 09:46:35,470] Trial 41 finished with value: 0.04751407539291679 and parameters: {'lambda_l1': 0.1806171422947859, 'lambda_l2': 5.434351368642456e-07}. Best is trial 40 with value: 0.04732918655158931.
# regularization_factors, val_score: 0.047329:  15%|#5        | 3/20 [00:01<00:07,  2.27it/s][I 2021-01-05 09:46:35,913] Trial 42 finished with value: 0.0478880284670659 and parameters: {'lambda_l1': 0.14803805979739743, 'lambda_l2': 5.911365472109529e-07}. Best is trial 40 with value: 0.04732918655158931.
# regularization_factors, val_score: 0.047329:  20%|##        | 4/20 [00:01<00:06,  2.36it/s][I 2021-01-05 09:46:36,300] Trial 43 finished with value: 0.047833017328209625 and parameters: {'lambda_l1': 0.13569219340312852, 'lambda_l2': 3.791665945270006e-07}. Best is trial 40 with value: 0.04732918655158931.
# regularization_factors, val_score: 0.047329:  25%|##5       | 5/20 [00:02<00:06,  2.43it/s][I 2021-01-05 09:46:36,686] Trial 44 finished with value: 0.04774578777362256 and parameters: {'lambda_l1': 0.21950533202990838, 'lambda_l2': 3.5738808001946643e-07}. Best is trial 40 with value: 0.04732918655158931.
# regularization_factors, val_score: 0.047329:  30%|###       | 6/20 [00:02<00:05,  2.48it/s][I 2021-01-05 09:46:37,068] Trial 45 finished with value: 0.047750673121832184 and parameters: {'lambda_l1': 0.132757055518808, 'lambda_l2': 4.831188824673222e-07}. Best is trial 40 with value: 0.04732918655158931.
# regularization_factors, val_score: 0.047329:  35%|###5      | 7/20 [00:02<00:05,  2.54it/s][I 2021-01-05 09:46:37,439] Trial 46 finished with value: 0.04797991135639443 and parameters: {'lambda_l1': 0.15288156810325618, 'lambda_l2': 4.032342785899912e-07}. Best is trial 40 with value: 0.04732918655158931.
# regularization_factors, val_score: 0.047329:  40%|####      | 8/20 [00:03<00:04,  2.53it/s][I 2021-01-05 09:46:37,838] Trial 47 finished with value: 0.047440682138603335 and parameters: {'lambda_l1': 0.17588587598855446, 'lambda_l2': 3.229281282620181e-07}. Best is trial 40 with value: 0.04732918655158931.
# regularization_factors, val_score: 0.047329:  45%|####5     | 9/20 [00:03<00:03,  2.88it/s][I 2021-01-05 09:46:38,072] Trial 48 finished with value: 0.049438999782306564 and parameters: {'lambda_l1': 4.936753019445165, 'lambda_l2': 0.00112557046238533}. Best is trial 40 with value: 0.04732918655158931.
# regularization_factors, val_score: 0.047213:  50%|#####     | 10/20 [00:03<00:03,  2.74it/s][I 2021-01-05 09:46:38,480] Trial 49 finished with value: 0.047212692921258625 and parameters: {'lambda_l1': 9.951680645770171e-05, 'lambda_l2': 2.6118076406116895e-08}. Best is trial 49 with value: 0.047212692921258625.
and parameters: {'min_child_samples': 5}. Best is trial 60 with value: 0.04721230885598156.
# min_data_in_leaf, val_score: 0.047212:  40%|####      | 2/5 [00:01<00:01,  1.97it/s][I 2021-01-05 09:46:44,253] Trial 61 finished with value: 0.04721230885598156 and parameters: {'min_child_samples': 25}. Best is trial 60 with value: 0.04721230885598156.
# min_data_in_leaf, val_score: 0.047212:  60%|######    | 3/5 [00:01<00:01,  1.99it/s][I 2021-01-05 09:46:44,746] Trial 62 finished with value: 0.04721230885598156 and parameters: {'min_child_samples': 50}. Best is trial 60 with value: 0.04721230885598156.
# min_data_in_leaf, val_score: 0.047212:  80%|########  | 4/5 [00:02<00:00,  1.76it/s][I 2021-01-05 09:46:45,471] Trial 63 finished with value: 0.04721230885598156 and parameters: {'min_child_samples': 100}. Best is trial 60 with value: 0.04721230885598156.
# min_data_in_leaf, val_score: 0.047212: 100%|##########| 5/5 [00:02<00:00,  1.82it/s][I 2021-01-05 09:46:45,978] Trial 64 finished with value: 0.04721230885598156 and parameters: {'min_child_samples': 10}. Best is trial 60 with value: 0.04721230885598156.
# min_data_in_leaf, val_score: 0.047212: 100%|##########| 5/5 [00:02<00:00,  1.83it/s]
# [I 2021-01-05 09:46:45,986] Trial 49 finished with value: 0.5 and parameters: {'lambda_l1': 0.018699796898410156, 'lambda_l2': 2.4209390326926397e-06, 'num_leaves': 471, 'feature_fraction': 0.7405827843177853, 'bagging_fraction': 0.5983605700969947, 'bagging_freq': 5, 'min_child_samples': 94}. Best is trial 0 with value: 0.5.

# %%
#ベストパラメータ
print('Number of finished trials:', len(study.trials))
#Number of finished trials: 50
# Out:
# Number of finished trials: 50

# %%
print('Best trial:', display(study.best_trial.params))

#初回
# {'lambda_l1': 5.204866804465978e-08,
#  'lambda_l2': 3.133667635701077e-05,
#  'num_leaves': 317,
#  'feature_fraction': 0.848640913268004,
#  'bagging_fraction': 0.4983467582046316,
#  'bagging_freq': 4,
#  'min_child_samples': 22}
# Best trial: None

#2回目
# {'lambda_l1': 0.00416566836241902,
#  'lambda_l2': 0.10371698288325823,
#  'num_leaves': 333,
#  'feature_fraction': 0.6873251818776734,
#  'bagging_fraction': 0.6363448284692337,
#  'bagging_freq': 10,
#  'min_child_samples': 17}
# Best trial: None
# Out:
# {'lambda_l1': 0.00416566836241902,
#  'lambda_l2': 0.10371698288325823,
#  'num_leaves': 333,
#  'feature_fraction': 0.6873251818776734,
#  'bagging_fraction': 0.6363448284692337,
#  'bagging_freq': 10,
#  'min_child_samples': 17}
# Best trial: None

# %%
# def create_feature_together(train, test, num_cols):
#     train, test = transform_box_cox(train, test, num_cols)
#     return train, test

# # issue 14 Box-Cox変換
# def transform_box_cox(train, test, column):
#     pt = PowerTransformer(method='box-cox')
#     pt.fit(train[column])

#     # 変換後のデータで各列を置換
#     train[column] = pt.transform(train[column])
#     test[column] = pt.transform(test[column])

#特徴量作成（train_dataとtest_dataで同一の処理が必要）
#変換するカラム
# num_cols = ['all_purchase_price']
# train_data, test_data = create_feature_together(train_data, test_data, num_cols)

# %%
# tr_x, va_x, tr_y, va_y = train_test_split(train_x, train_y,
#                                           test_size=0.25, random_state=71, shuffle=True)
# kf = KFold(n_splits=4, shuffle=True, random_state=71)
# for tr_idx, va_idx in kf.split(train_x):
#     tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
#     tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]
