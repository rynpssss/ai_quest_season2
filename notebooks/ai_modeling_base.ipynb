# %%
import pandas as pd
import numpy as np

import datetime
import jpholiday
import statsmodels.api as sm
from statsmodels.graphics import tsaplots
import lightgbm as lgb
from sklearn.metrics import  log_loss
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from datetime import date, timedelta
from dateutil.relativedelta import relativedelta

# %matplotlib inline

# %% [markdown]
# # 基準モデルの作成

# %%
FILE_PATH = '/Users/atsushisato/Google_drive/05_PBL/second_section/practice_4/ai_modeling/data/'

train_data = pd.read_csv(FILE_PATH + 'external/train.csv').rename(columns={'顧客ID':'uuid', 'クーポンID':'coupon_id', 'クーポン利用':'coupon_use_result'})
test_data = pd.read_csv(FILE_PATH + 'external/test.csv').rename(columns={'顧客ID':'uuid', 'クーポンID':'coupon_id'})
customer_df = pd.read_csv(FILE_PATH + 'interim/customer_df.csv')

# %%
def category_to_int_conversion(dataframe):
    marry_dict = {'無回答':-1, '独身':0, '既婚':1}
    dataframe['age'] = dataframe['age_range'].apply(lambda x: int(x[:2]))
    dataframe['marry_flg'] = dataframe['marry'].apply(lambda x: marry_dict.get(x))
    dataframe['category_id'] = dataframe['category_id'].apply(lambda x: int(x[1:]))
    
    dataframe = dataframe.drop(['age_range', 'marry', 'category'],axis=1)
    return dataframe

# %%
#train_dataとtest_data
train_data = pd.merge(train_data, customer_df, on=['uuid', 'coupon_id'],how='inner')
test_data = pd.merge(test_data, customer_df, on=['uuid', 'coupon_id'],how='inner')

#カテゴリ変数の数値変換
train_data = category_to_int_conversion(train_data)
test_data = category_to_int_conversion(test_data)

# %%
train_data.head()
# Out:
#    uuid  coupon_id  coupon_use_result  fammily_num  child_num  house_flg  \
# 0     1          1                  0            1          0          0
# 1     1          2                  0            1          0          0
# 2     1          3                  0            1          0          0
# 3     1          4                  0            1          0          0
# 4     1          5                  0            1          0          0
#
#    income  visits_frequency  pass_days  all_purchase_price  purchase_num  \
# 0       5                 9         19               56562             1
# 1       5                 9         19               56562             1
# 2       5                 9         19               56562             0
# 3       5                 9         19               56562             1
# 4       5                 9         19               56562             9
#
#    purchase_product_num  coupon_use  purchase_price  category_id  age  \
# 0                     2           0             534            1   40
# 1                     2           0            2803            2   40
# 2                     0           0               0            3   40
# 3                     1           0             764            4   40
# 4                    17           0            4981            5   40
#
#    marry_flg
# 0         -1
# 1         -1
# 2         -1
# 3         -1
# 4         -1

# %%
uuid_num = train_data['uuid'].nunique()

train = train_data.query(f"uuid <= {int(uuid_num/2)}")
train_x = train.drop('coupon_use_result', axis=1)
train_y = train[['coupon_use_result']]

va = train_data.query(f"uuid > {int(uuid_num/2)}")
va_x = va.drop('coupon_use_result',axis=1)
va_y = va[['coupon_use_result']]

# %%
#LightGBMによるモデル作成
# params = {,
#           'application':'binary',  
#           'seed':71, 
#           'verbose':0, 
#           'metrics':'binary_logloss'}
params = {
    'boosting': 'dart',          # dart (drop out trees) often performs better
    'application': 'binary',     # Binary classification
    'learning_rate': 0.05,       # Learning rate, controls size of a gradient descent step
    'min_data_in_leaf': 20,      # Data set is quite small so reduce this a bit
    'feature_fraction': 0.7,     # Proportion of features in each boost, controls overfitting
    'num_leaves': 41,            # Controls size of tree since LGBM uses leaf wise splits
    'metric': 'binary_logloss',  # Area under ROC curve as the evaulation metric
    'drop_rate': 0.15
              }
num_round =100
# category = ['age', 'marry_flg', 'category_id']

lgb_train = lgb.Dataset(train_x, train_y)
lgb_eval = lgb.Dataset(va_x, va_y)
model = lgb.train(params, 
                  lgb_train, 
                  num_boost_round=num_round, 
                  valid_names=['train', 'valid'], 
                  valid_sets=[lgb_train, lgb_eval])
# Out:
# [1]	train's binary_logloss: 0.0776435	valid's binary_logloss: 0.0510303
# [2]	train's binary_logloss: 0.0724943	valid's binary_logloss: 0.0497625
# [3]	train's binary_logloss: 0.068638	valid's binary_logloss: 0.0487397
# [4]	train's binary_logloss: 0.0648071	valid's binary_logloss: 0.0484645
# [5]	train's binary_logloss: 0.0622425	valid's binary_logloss: 0.0483827
# [6]	train's binary_logloss: 0.0598444	valid's binary_logloss: 0.0481127
# [7]	train's binary_logloss: 0.057654	valid's binary_logloss: 0.0476082
# [8]	train's binary_logloss: 0.0590959	valid's binary_logloss: 0.0478408
# [9]	train's binary_logloss: 0.0569898	valid's binary_logloss: 0.0474458
# [10]	train's binary_logloss: 0.0547527	valid's binary_logloss: 0.0471251
# [11]	train's binary_logloss: 0.0544864	valid's binary_logloss: 0.0470502
# [12]	train's binary_logloss: 0.05521	valid's binary_logloss: 0.0470362
# [13]	train's binary_logloss: 0.0530732	valid's binary_logloss: 0.0468061
# [14]	train's binary_logloss: 0.0539171	valid's binary_logloss: 0.0469459
# [15]	train's binary_logloss: 0.0518645	valid's binary_logloss: 0.0467053
# [16]	train's binary_logloss: 0.050102	valid's binary_logloss: 0.0467053
# [17]	train's binary_logloss: 0.0485572	valid's binary_logloss: 0.0466983
# [18]	train's binary_logloss: 0.046853	valid's binary_logloss: 0.0464497
# [19]	train's binary_logloss: 0.0452435	valid's binary_logloss: 0.0460448
# [20]	train's binary_logloss: 0.0437227	valid's binary_logloss: 0.0458542
# [21]	train's binary_logloss: 0.0442503	valid's binary_logloss: 0.0458307
# [22]	train's binary_logloss: 0.0428584	valid's binary_logloss: 0.0455337
# [23]	train's binary_logloss: 0.0414297	valid's binary_logloss: 0.0453386
# [24]	train's binary_logloss: 0.040039	valid's binary_logloss: 0.0451821
# [25]	train's binary_logloss: 0.0388143	valid's binary_logloss: 0.045309
# [26]	train's binary_logloss: 0.0376486	valid's binary_logloss: 0.0453474
# [27]	train's binary_logloss: 0.0364762	valid's binary_logloss: 0.0451877
# [28]	train's binary_logloss: 0.0370795	valid's binary_logloss: 0.0451224
# [29]	train's binary_logloss: 0.0360345	valid's binary_logloss: 0.0449538
# [30]	train's binary_logloss: 0.0351187	valid's binary_logloss: 0.0449142
# [31]	train's binary_logloss: 0.0356497	valid's binary_logloss: 0.0447772
# [32]	train's binary_logloss: 0.0347616	valid's binary_logloss: 0.0448113
# [33]	train's binary_logloss: 0.0339521	valid's binary_logloss: 0.0448135
# [34]	train's binary_logloss: 0.0328505	valid's binary_logloss: 0.0445482
# [35]	train's binary_logloss: 0.0334447	valid's binary_logloss: 0.0445524
# [36]	train's binary_logloss: 0.0361058	valid's binary_logloss: 0.0462545
# [37]	train's binary_logloss: 0.0351766	valid's binary_logloss: 0.0460823
# [38]	train's binary_logloss: 0.0344251	valid's binary_logloss: 0.0459486
# [39]	train's binary_logloss: 0.0336579	valid's binary_logloss: 0.0458946
# [40]	train's binary_logloss: 0.0340267	valid's binary_logloss: 0.0458932
# [41]	train's binary_logloss: 0.0346765	valid's binary_logloss: 0.0459586
# [42]	train's binary_logloss: 0.0338128	valid's binary_logloss: 0.0456717
# [43]	train's binary_logloss: 0.034404	valid's binary_logloss: 0.0457291
# [44]	train's binary_logloss: 0.0336854	valid's binary_logloss: 0.0456459
# [45]	train's binary_logloss: 0.0328618	valid's binary_logloss: 0.0454159
# [46]	train's binary_logloss: 0.0377069	valid's binary_logloss: 0.0487676
# [47]	train's binary_logloss: 0.0368041	valid's binary_logloss: 0.0484396
# [48]	train's binary_logloss: 0.0373589	valid's binary_logloss: 0.0484494
# [49]	train's binary_logloss: 0.037804	valid's binary_logloss: 0.0484787
# [50]	train's binary_logloss: 0.0383833	valid's binary_logloss: 0.0485903
# [51]	train's binary_logloss: 0.0375469	valid's binary_logloss: 0.0483174
# [52]	train's binary_logloss: 0.0366946	valid's binary_logloss: 0.0480848
# [53]	train's binary_logloss: 0.0372672	valid's binary_logloss: 0.0481186
# [54]	train's binary_logloss: 0.0364634	valid's binary_logloss: 0.0478712
# [55]	train's binary_logloss: 0.0355928	valid's binary_logloss: 0.0474885
# [56]	train's binary_logloss: 0.036226	valid's binary_logloss: 0.0475936
# [57]	train's binary_logloss: 0.0353814	valid's binary_logloss: 0.0472138
# [58]	train's binary_logloss: 0.0407113	valid's binary_logloss: 0.0512081
# [59]	train's binary_logloss: 0.0412373	valid's binary_logloss: 0.0513726
# [60]	train's binary_logloss: 0.0403191	valid's binary_logloss: 0.0508042
# [61]	train's binary_logloss: 0.0473971	valid's binary_logloss: 0.0563087
# [62]	train's binary_logloss: 0.0461171	valid's binary_logloss: 0.0553984
# [63]	train's binary_logloss: 0.0448285	valid's binary_logloss: 0.0545771
# [64]	train's binary_logloss: 0.0453319	valid's binary_logloss: 0.0547157
# [65]	train's binary_logloss: 0.0460266	valid's binary_logloss: 0.0550545
# [66]	train's binary_logloss: 0.0447755	valid's binary_logloss: 0.0542259
# [67]	train's binary_logloss: 0.0435406	valid's binary_logloss: 0.0535606
# [68]	train's binary_logloss: 0.042433	valid's binary_logloss: 0.0528891
# [69]	train's binary_logloss: 0.0431086	valid's binary_logloss: 0.0532313
# [70]	train's binary_logloss: 0.043514	valid's binary_logloss: 0.0534048
# [71]	train's binary_logloss: 0.0439217	valid's binary_logloss: 0.0535071
# [72]	train's binary_logloss: 0.0428368	valid's binary_logloss: 0.0528528
# [73]	train's binary_logloss: 0.0417441	valid's binary_logloss: 0.0520366
# [74]	train's binary_logloss: 0.042246	valid's binary_logloss: 0.052279
# [75]	train's binary_logloss: 0.0411823	valid's binary_logloss: 0.0517018
# [76]	train's binary_logloss: 0.0418235	valid's binary_logloss: 0.0520561
# [77]	train's binary_logloss: 0.0421807	valid's binary_logloss: 0.0521796
# [78]	train's binary_logloss: 0.0424975	valid's binary_logloss: 0.0522554
# [79]	train's binary_logloss: 0.04149	valid's binary_logloss: 0.0516248
# [80]	train's binary_logloss: 0.0404891	valid's binary_logloss: 0.0508732
# [81]	train's binary_logloss: 0.0409516	valid's binary_logloss: 0.0511101
# [82]	train's binary_logloss: 0.0399941	valid's binary_logloss: 0.0504098
# [83]	train's binary_logloss: 0.0404549	valid's binary_logloss: 0.0505462
# [84]	train's binary_logloss: 0.0410831	valid's binary_logloss: 0.0508346
# [85]	train's binary_logloss: 0.0415511	valid's binary_logloss: 0.0510335
# [86]	train's binary_logloss: 0.0406051	valid's binary_logloss: 0.0504532
# [87]	train's binary_logloss: 0.0396269	valid's binary_logloss: 0.0499809
# [88]	train's binary_logloss: 0.0402153	valid's binary_logloss: 0.0502021
# [89]	train's binary_logloss: 0.0407029	valid's binary_logloss: 0.050347
# [90]	train's binary_logloss: 0.0411776	valid's binary_logloss: 0.0505728
# [91]	train's binary_logloss: 0.0461054	valid's binary_logloss: 0.0545188
# [92]	train's binary_logloss: 0.0449289	valid's binary_logloss: 0.0539165
# [93]	train's binary_logloss: 0.0438044	valid's binary_logloss: 0.0532069
# [94]	train's binary_logloss: 0.0443615	valid's binary_logloss: 0.0534929
# [95]	train's binary_logloss: 0.0448747	valid's binary_logloss: 0.0537378
# [96]	train's binary_logloss: 0.045263	valid's binary_logloss: 0.0539507
# [97]	train's binary_logloss: 0.0440701	valid's binary_logloss: 0.0532469
# [98]	train's binary_logloss: 0.0446666	valid's binary_logloss: 0.0535033
# [99]	train's binary_logloss: 0.0435479	valid's binary_logloss: 0.0529421
# [100]	train's binary_logloss: 0.0424399	valid's binary_logloss: 0.0522219

# %%
pred = model.predict(test_data)
pred = pd.Series(pred, name='pred')

# %%
pred
# Out:
# 0       0.014780
# 1       0.016337
# 2       0.016046
# 3       0.014904
# 4       0.043826
#           ...
# 3911    0.013810
# 3912    0.035418
# 3913    0.013796
# 3914    0.014941
# 3915    0.017317
# Name: pred, Length: 3916, dtype: float64

# %%
result = test_data.join(pred)[['uuid', 'coupon_id', 'pred']]
result = result.pivot(index='uuid', columns='coupon_id', values='pred')

# %%
result.to_csv('/Users/atsushisato/Google_drive/05_PBL/second_section/practice_4/ai_modeling/models/first_model.csv',header=False)
